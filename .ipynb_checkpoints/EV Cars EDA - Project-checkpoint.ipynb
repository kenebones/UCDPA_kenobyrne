# %% [markdown]
# I live a long distance from where I work, I am able to work from home two days a week but my daily commute is 159km.
# So even on a three day week just using the car for work means that I drive close to 500km a week.
# My annual distance driven is around 35,000km.
# I have driven diesel cars over the last few years due to their fuel economy#With fuel prices increasing, along with enviromental considerations, I am considering moving away from diesel cars.
# I would like to investigate the feasability of me switching to a fully electric car as Hybrids and Plug in Hybrids
# will not meet my requirements.
# I will look at the currently available Battery Electric Vehicles to see if any would meet my needs .
# Budget is also a consideration, both from the perspective of the cost of the car and the cost of running the car.

# %%
# importing libraries
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import pandas as pd

#Pulling the html code from ev-database.org electric cars webpage

url='https://ev-database.org/#sort:path~type~order=.rank~number~desc|range-slider-range:prev~next=0~1200|range-slider-acceleration:prev~next=2~23|range-slider-topspeed:prev~next=110~450|range-slider-battery:prev~next=10~200|range-slider-towweight:prev~next=0~2500|range-slider-fastcharge:prev~next=0~1500|paging:currentPage=0|paging:number=all'

data=requests.get(url)

pprint(data.text)
# Out:
# ('<!doctype html>\r\n'
#  '<html lang="en">\r\n'
#  '\t<!-- head -->\r\n'
#  '\t<head>\t\t\n'
#  '\t<meta charset="utf-8" />\n'
#  '\t\t<link rel="canonical" href="https://ev-database.org/">\t<link '
#  'rel="alternate" hreflang="en-gb" href="https://ev-database.uk/">\t<link '
#  'rel="alternate" hreflang="de" href="https://ev-database.de/">\t<link '
#  'rel="alternate" hreflang="nl" href="https://ev-database.nl/">\t<link '
#  'rel="alternate" hreflang="x-default" href="https://ev-database.org/">\t<meta '
#  'name="viewport" content="width=device-width, initial-scale=1" />\n'
#  '\t<title>Compare electric vehicles - EV Database</title>\n'
#  '\t\t<meta name="description" content="A complete overview of all electric '
#  'vehicles in Europe. Search and compare by range, make, model and price.">\n'
#  '\n'
#  '\t<meta property="og:title" content="EV Database" />\n'
#  '\t<meta property="og:description" content="A complete overview of all '
#  'electric vehicles in Europe. Search and compare by range, make, model and '
#  'price." />\n'
#  '\t<meta property="og:type" content="website" />\n'
#  '\t<meta property="og:url" content="https://ev-database.org/" />\n'
#  '\t<meta property="og:image" '
#  'content="https://ev-database.org/img/common/android-icon-192x192.png" />\n'
#  '\t<meta property="og:site_name" content="EV Database" />\n'
#  '\t<meta property="og:locale" content="en" />\n'
#  '\n'
#  '\t<meta http-equiv="content-language" content="en">\n'
#  '\n'
#  '\t<link rel="shortcut icon" href="/android-chrome-512x512.png">\n'
#  '\t<link rel="apple-touch-icon" sizes="180x180" '
#  'href="/apple-touch-icon.png">\n'
#  '\t<link rel="icon" type="image/png" sizes="32x32" '
#  'href="/favicon-32x32.png">\n'
#  '\t<link rel="icon" type="image/png" sizes="16x16" '
#  'href="/favicon-16x16.png">\n'
#  '\t<link rel="manifest" href="/site.webmanifest">\n'
#  '\t<link rel="mask-icon" href="/safari-pinned-tab.svg" color="#767676">\n'
#  '\t<meta name="msapplication-TileColor" content="#603cba">\n'
#  '\t<meta name="theme-color" content="#ffffff">\n'
#  '\t\n'
#  '\t<link href="https://fonts.googleapis.com/css?family=Lato:400,300" '
#  'rel="stylesheet" type="text/css" />\n'
#  '\t<link href="/css/fa-5/fontawesome.min.css" rel="stylesheet">\n'
#  '\t<link href="/css/fa-5/solid.min.css" rel="stylesheet">\n'
#  '\t<link href="/css/fa-5/regular.min.css" rel="stylesheet">\t\n'
#  '\t<link href="/css/dynamic/style.css?u=si&l=si&p=index&v=4.3" '
#  'rel="stylesheet" type="text/css" />\n'
#  '\n'
#  '\t<script '
#  'src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>\n'
#  '\t\t\n'
#  '\t<script '
#  'src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>\t\t\t\t\t\t\n'
#  '\t<link '
#  'href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.min.css" '
#  'rel="stylesheet" type="text/css">\t\n'
#  '\t<script src="/js/dynamic/script.js?u=si&l=si&p=index&v=4.3"></script>\n'
#  '\n'
#  '\t<script>\n'
#  '\twindow.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new '
#  'Date;\n'
#  "\tga('create', 'UA-72820721-3', 'auto');\n"
#  "\tga('send', 'pageview');\n"
#  '\t</script>\n'
#  '\t<script async '
#  "src='https://www.google-analytics.com/analytics.js'></script>\n"
#  '\n'
#  '\t<script>\n'
#  '\tvar trackOutboundLink = function(url) {\n'
#  "\t\t ga('send', 'event', 'outbound', 'click', url);\n"
#  '\t}\n'
#  '\t</script>\t\n'
#  '\t\n'
#  '\n'
#  '\n'
#  '\t<script async '
#  'src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n'
#  '\t\n'
#  '\t<script>\n'
#  '\t\t(adsbygoogle = window.adsbygoogle || []).push({\n'
#  '\t\tgoogle_ad_client: "ca-pub-5409517482266138",\n'
#  '\t\tenable_page_level_ads: false,\n'
#  '\t\toverlays: {bottom: true}\n'
#  '\t\t});\n'
#  '\t</script>\n'
#  '\n'
#  '</head> \r\n'
#  '\t<body id="evdb">\r\n'
#  '\t\t<!-- header -->\r\n'
#  '\t\t<header id="header">\n'
#  '\n'
#  '\t<div class="header-top-row">\n'
#  '\t\t<section>\t\t\t\t\t\t\t\t\t\n'
#  '\t\t\t<div class="header-logo">\n'
#  '\t\t\t<a href="/"><img src="/img/common/EVDB-Logo-EN.svg" width="210" '
#  'alt="EV Database Logo"></a>\t\t\t</div>\n'
#  '\n'
#  '      <div class="header-top-right">\n'
#  '                <div class="header-select-units">\n'
#  '          <select id="select_units">\n'
#  '            <option value="/" selected>Metric</option>\n'
#  '            <option value="/imp/" >UK Imperial</option>\n'
#  '          </select>\n'
#  '        </div>\n'
#  '        \n'
#  '        <div class="header-search">\n'
#  '          <div class="jplist-panel text-filter-box">\n'
#  '              \n'
#  '              <input \n'
#  '               data-path=".title" \n'
#  '               type="text" \n'
#  '               value="" \n'
#  '               placeholder="Search..."\n'
#  '               data-control-type="textbox" \n'
#  '               data-control-name="title-filter" \n'
#  '               data-control-action="filter"\n'
#  '               maxlength="20"\n'
#  '              />\t\t\t\t\t\n'
#  '    \n'
#  '              <i class="fas fa-search text-filter-icon"></i>\n'
#  '    \n'
#  '            \t\t\t\t\t\t\t\t\t\n'
#  '          </div>\n'
#  '        </div>\n'
#  '      </div>\t\t\t\n'
#  '\t\t</section>\n'
#  '\t</div>\t\t\t\t\t\t\t\t\n'
#  '\n'
#  '\t<div class="header-bot-row">\t\t\t\t\t\t\t\t\t\n'
#  '\t\t<nav>\n'
#  '\t\t\t<ul>\n'
#  '\t\t\t\t<li><a href="/compare/newest-upcoming-electric-vehicle">MOST '
#  'RECENT</a></li>\n'
#  '\t\t\t\t\t\t\t\t\t<li><a href="/compare/cheapest-electric-vehicle">CHEAPEST '
#  'EV</a></li>\n'
#  '\t\t\t\t\t\t\t\t\t<li><a '
#  'href="/compare/electric-vehicle-car-towing-capacity-weight">TOWING</a></li><li><a '
#  'href="/compare/fast-charging-electric-vehicle-quickest">FASTCHARGING</a></li><li><a '
#  'href="/compare/efficiency-electric-vehicle-most-efficient">MOST '
#  'EFFICIENT</a></li><li><a '
#  'href="/compare/electric-vehicle-longest-range">LONGEST RANGE</a></li>\t\t\t'
#  '</ul>\n'
#  '\t\t</nav>\n'
#  '\t</div>\n'
#  '\t\n'
#  '\t<div class="mobile-nav">\n'
#  '\t\t<div class="menu-btn" id="menu-btn">\n'
#  '\t\t\t<div></div>\n'
#  '\t\t\t<span></span>\n'
#  '\t\t\t<span></span>\n'
#  '\t\t\t<span></span>\n'
#  '\t\t</div>\n'
#  '\n'
#  '\t\t <div class="responsive-menu">\n'
#  '\t\t\t<div class="menu-header"> \n'
#  '\t\t\t\t<nav> \n'
#  '\t\t\t\t\t<ul class="menu" id="menu-mobile-menu">\n'
#  '\t\t\t\t\t\t<li><a href="/compare/newest-upcoming-electric-vehicle">MOST '
#  'RECENT</a></li>\n'
#  '\t\t\t\t\t\t\t\t\t<li><a href="/compare/cheapest-electric-vehicle">CHEAPEST '
#  'EV</a></li>\n'
#  '\t\t\t\t\t\t\t\t\t<li><a '
#  'href="/compare/electric-vehicle-car-towing-capacity-weight">TOWING</a></li><li><a '
#  'href="/compare/fast-charging-electric-vehicle-quickest">FASTCHARGING</a></li><li><a '
#  'href="/compare/efficiency-electric-vehicle-most-efficient">MOST '
#  'EFFICIENT</a></li><li><a '
#  'href="/compare/electric-vehicle-longest-range">LONGEST '
#  'RANGE</a></li>\t\t\t\t\t\t            <li class="jplist-panel '
#  'text-filter-box">\n'
#  '                <input \n'
#  '                 data-path=".title" \n'
#  '                 type="text" \n'
#  '                 placeholder="Search..."\n'
#  '                 data-control-type="textbox" \n'
#  '                 data-control-name="title-filter-mobile" \n'
#  '                 data-control-action="filter"\n'
#  '                 maxlength="20"\n'
#  '                />\n'
#  '            </li>\n'
#  '            \t\n'
#  '\t\t\t\t\t</ul>\n'
#  '\t\t\t\t</nav>\n'
#  '\t\t\t</div>\n'
#  '\t\t </div>\n'
#  '\t</div>\n'
#  '\t\t\t\t\t\t\n'
#  '</header>\r\n'
#  '\t\t<!-- main content -->\r\n'
#  '\t\t<main>\r\n'
#  '\r\n'
#  '\t\t\t\t\r\n'
#  '\t\t\t<div align="center" class="adslot_index1">\r\n'
#  '\t\t\t\t<!-- Homepage-Responsive -->\r\n'
#  '\t\t\t\t<ins class="adsbygoogle adslot_control_index1"\r\n'
#  '          data-ad-client="ca-pub-5409517482266138"\r\n'
#  '          data-ad-slot="9809755005"></ins>\r\n'
#  '\t\t\t\t<script>\r\n'
#  '\t\t\t\t(adsbygoogle = window.adsbygoogle || []).push({});\r\n'
#  '\t\t\t\t</script>\r\n'
#  '\t\t\t</div>\r\n'
#  '\t\t\t\r\n'
#  '\t\t\t<div class="content jplist">\r\n'
#  '\r\n'
#  '\t\t\t\t<!-- panel-top -->\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n'
#  '\t\t\t\t<!-- panel-top-header -->\n'
#  '<div class="jplist-panel panel-header sub-header">    \n'
#  '\t\n'
#  '\t<div class="subheader-title">\n'
#  '\t\t<h1>All electric vehicles</h1>\n'
#  '    <span\n'
#  '    data-control-type="counter"\n'
#  '    data-control-action="counter"\n'
#  '    data-control-name="all-counter"\n'
#  '    data-format="{count} cars found"\n'
#  '    data-path=".data-wrapper"\n'
#  '    data-mode="filter"\n'
#  '    data-type="path">\n'
#  '    </span>  \n'
#  '\t</div>\n'
#  '       \n'
#  '\t<div class="sort-reset">\t\n'
#  '\t\t<!-- sort dropdown -->\n'
#  '\t\t<div \n'
#  '\t\t\tclass="jplist-drop-down" \n'
#  '\t\t\tdata-control-type="sort-drop-down" \n'
#  '\t\t\tdata-control-name="sort" \n'
#  '\t\t\tdata-control-action="sort">\n'
#  '\n'
#  '\t\t\t<ul>  \n'
#  '\t\t\t<li><span data-path=".rank" data-order="desc" data-type="number">Most '
#  'Viewed</span></li>         \n'
#  '\t\t\t<li><span data-path=".id" data-order="desc" data-type="number" >Most '
#  'Recent</span></li>         \n'
#  '\t\t\t<li><span data-path=".title" data-order="asc" '
#  'data-type="text">Alphabetic</span></li>         \n'
#  '\t\t\t<li><span data-path=".price" data-order="asc" data-type="number" '
#  '>Price Low-High</span></li>\n'
#  '\t\t\t<li><span data-path=".price" data-order="desc" '
#  'data-type="number">Price High-Low</span></li>\n'
#  '\t\t\t<li><span data-path=".erange_real" data-order="desc" '
#  'data-type="number" >Range</span></li>          \n'
#  '\t\t\t<li><span data-path=".efficiency" data-order="asc" data-type="number" '
#  '>Efficiency</span></li>\n'
#  '\t\t\t<li><span data-path=".fastcharge_speed" data-order="desc" '
#  'data-type="number" >Fastcharging</span></li>\n'
#  '\t\t\t<li><span data-path=".acceleration" data-order="asc" '
#  'data-type="number" >Acceleration</span></li>\n'
#  '\t\t\t<li><span data-path=".towweight" data-order="desc" data-type="number" '
#  '>Towing Capacity</span></li>         \n'
#  '\t\t\t  \n'
#  '\t\t\t\t<li><span data-path=".date_from" data-order="desc" '
#  'data-type="number" >Date Available</span></li>\n'
#  '\t\t\t\t\t\t</ul>\n'
#  '\t\t</div>\n'
#  '\n'
#  '\t\t<!-- reset button -->\n'
#  '\t\t<button \n'
#  '\t\ttype="button" \n'
#  '\t\tclass="jplist-reset-btn"\n'
#  '\t\tdata-control-type="reset" \n'
#  '\t\tdata-control-name="reset" \n'
#  '\t\tdata-control-action="reset">\n'
#  '\t\tReset &nbsp;<i class="fas fa-share"></i>\n'
#  '\t\t</button>       \n'
#  '\t</div>\n'
#  '\t\t\n'
#  '</div>     \n'
#  '\n'
#  '<!-- panel-top-main -->\n'
#  '<div class="jplist-panel panel-top">\n'
#  '       \n'
#  '\t<div id="default-options">\n'
#  '\n'
#  '\t\t<!-- first row options -->\n'
#  '\t\t<div class="first-row-options">\t\n'
#  '\t\t\t\t\t\t\t\n'
#  '\t\t\t<!-- make dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="make-checkbox-dropdown" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Make"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} selected">\n'
#  '\t\t\t\t<ul>\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".aiways" id="aiways" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="aiways">Aiways\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="aiways-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".aiways"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".audi" id="audi" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="audi">Audi\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="audi-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".audi"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".bmw" id="bmw" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="bmw">BMW\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="bmw-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".bmw"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".citroen" id="citroen" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="citroen">Citroen\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="citroen-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".citroen"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".cupra" id="cupra" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="cupra">CUPRA\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="cupra-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".cupra"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".dacia" id="dacia" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="dacia">Dacia\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="dacia-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".dacia"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".ds" id="ds" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="ds">DS\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="ds-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".ds"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".fiat" id="fiat" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="fiat">Fiat\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="fiat-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".fiat"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".ford" id="ford" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="ford">Ford\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="ford-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".ford"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".genesis" id="genesis" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="genesis">Genesis\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="genesis-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".genesis"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".honda" id="honda" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="honda">Honda\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="honda-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".honda"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".hyundai" id="hyundai" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="hyundai">Hyundai\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="hyundai-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".hyundai"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".jac" id="jac" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="jac">JAC\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="jac-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".jac"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".jaguar" id="jaguar" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="jaguar">Jaguar\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="jaguar-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".jaguar"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".kia" id="kia" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="kia">Kia\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="kia-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".kia"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".lexus" id="lexus" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="lexus">Lexus\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="lexus-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".lexus"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".lightyear" id="lightyear" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="lightyear">Lightyear\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="lightyear-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".lightyear"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".lucid" id="lucid" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="lucid">Lucid\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="lucid-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".lucid"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".mazda" id="mazda" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="mazda">Mazda\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="mazda-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".mazda"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".mercedes" id="mercedes" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="mercedes">Mercedes\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="mercedes-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".mercedes"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".mg" id="mg" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="mg">MG\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="mg-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".mg"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".mini" id="mini" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="mini">Mini\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="mini-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".mini"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".nissan" id="nissan" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="nissan">Nissan\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="nissan-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".nissan"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".opel" id="opel" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="opel">Opel\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="opel-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".opel"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".peugeot" id="peugeot" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="peugeot">Peugeot\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="peugeot-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".peugeot"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".polestar" id="polestar" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="polestar">Polestar\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="polestar-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".polestar"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".porsche" id="porsche" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="porsche">Porsche\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="porsche-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".porsche"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".renault" id="renault" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="renault">Renault\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="renault-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".renault"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".seres" id="seres" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="seres">Seres\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="seres-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".seres"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".skoda" id="skoda" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="skoda">Skoda\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="skoda-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".skoda"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".smart" id="smart" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="smart">Smart\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="smart-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".smart"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".sono" id="sono" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="sono">Sono\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="sono-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".sono"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".ssangyong" id="ssangyong" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="ssangyong">SsangYong\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="ssangyong-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".ssangyong"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".subaru" id="subaru" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="subaru">Subaru\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="subaru-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".subaru"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".tesla" id="tesla" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="tesla">Tesla\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="tesla-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".tesla"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".toyota" id="toyota" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="toyota">Toyota\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="toyota-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".toyota"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".volkswagen" id="volkswagen" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="volkswagen">Volkswagen\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="volkswagen-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".volkswagen"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li><li>\n'
#  '\t\t\t\t\t\t<input data-path=".volvo" id="volvo" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="volvo">Volvo\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="volvo-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".volvo"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t\t</li>            \n'
#  '\t\t\t\t</ul>\n'
#  '\t\t\t</div> \n'
#  '\n'
#  '\t\t\t<!-- price dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="price-checkbox-dropdown" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Price"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} selected"\n'
#  '\t\t\t>\n'
#  '\n'
#  '\t\t\t\t<ul>\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".price_filter20-40" id="price_filter20-40" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="price_filter20-40">$\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="pf20-40-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".price_filter20-40"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>\n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>          \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".price_filter40-60" id="price_filter40-60" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="price_filter40-60">$$\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="pf40-60-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".price_filter40-60"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>\n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li> \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".price_filter60-80" id="price_filter60-80" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="price_filter60-80">$$$\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="pf60-80-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".price_filter60-80"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>\n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>           \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".price_filter80-100" id="price_filter80-100" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="price_filter80-100">$$$$\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="pf80-100-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".price_filter80-100"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>\n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li> \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".price_filter100" id="price_filter100" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="price_filter100">$$$$$\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="pf100-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".price_filter100"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>\n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li> \n'
#  '\t\t\t\t</ul>\n'
#  '\t\t\t</div> \n'
#  '\n'
#  '\t\t\t<!-- vormgeving dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="bodyshape-checkbox-dropdown" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Body Style"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} selected">\n'
#  '\n'
#  '\t\t\t<ul>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-hatchback" id="shape-hatchback" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-hatchback">Hatchback\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-hatchback-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-hatchback"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-sedan" id="shape-sedan" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-sedan">Sedan\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-sedan-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-sedan"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>  \t\t\t\t\t\n'
#  '  \n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-suv" id="shape-suv" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-suv">SUV\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-suv-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-suv"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>                   \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-mpv" id="shape-mpv" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-mpv">MPV\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-mpv-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-mpv"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-station" id="shape-station" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-station">Station/Estate\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-station-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-station"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>  \t\t\t\t\t\n'
#  '\n'
#  '\t\t\t\t  <li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-cabrio" id="shape-cabrio" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-cabrio">Cabriolet\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-cabrio-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-cabrio"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-spv" id="shape-spv" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-spv">Small Van\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-spv-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-spv"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>  \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".shape-pickup" id="shape-pickup" '
#  'type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="shape-pickup">Pickup Truck\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="shape-pickup-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".shape-pickup"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li> \n'
#  '\t\t\t</ul>\n'
#  '\t\t\t</div>\t\n'
#  '\n'
#  '\t\t\t<!-- availability dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown availability"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="availability-checkbox-dropdown" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Availability"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} selected">\n'
#  '\t\t\t\t<ul>\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".current" id="current" '
#  'type="checkbox">\t\t\t\t\t\t<label for="current">Available\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="current-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".current"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li> \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".not-current" id="not-current" '
#  'type="checkbox">\t\t\t\t\t\t<label for="not-current">Upcoming\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="not-current-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".not-current"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".is-concept" id="is-concept" '
#  'type="checkbox">\t\t\t\t\t\t<label for="is-concept">Concept\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="is-concept-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".is-concept"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>           \n'
#  '\t\t\t\t</ul>\n'
#  '\t\t\t</div>\n'
#  '\t\t</div>\n'
#  '\t\n'
#  '\t\t<!-- more options -->\n'
#  '\t\t<div id="toggle-more-options"><i class="fas fa-angle-double-down '
#  'fa-fw"></i>More Options</div>\n'
#  '\t\t\n'
#  '\t</div>\n'
#  '\n'
#  '\t<div id="more-options" class="box">\n'
#  '\t\t\n'
#  '\t\t<!-- second row options -->\n'
#  '\t\t<div class="box second-row-options">     \n'
#  '\t\t         \n'
#  '\t\t\t<!-- chargeplug dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="plug-cb-dd" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Charge Plug"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} geselecteerd"\n'
#  '\t\t\t>\n'
#  '\n'
#  '\t\t\t<ul>\n'
#  '\t\t\t\t <li>\n'
#  '\t\t\t\t <input data-path=".plug-type1" id="plug-type1" type="checkbox" />\n'
#  '\t\t\t\t\t<label for="plug-type1">Type 1\n'
#  '\t\t\t\t\t<span\n'
#  '\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\tdata-control-name="plug-type1-counter"\n'
#  '\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\tdata-path=".plug-type1"\n'
#  '\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t</span>\t\t\t\t\t\t\t\t  \n'
#  '\t\t\t\t\t</label>\n'
#  '\t\t\t\t </li>\n'
#  '\n'
#  '\t\t\t\t <li>\n'
#  '\t\t\t\t <input data-path=".plug-type1-cdm" id="plug-type1-cdm" '
#  'type="checkbox" />\n'
#  '\t\t\t\t\t<label for="plug-type1-cdm">Type 1 CHAdeMO\n'
#  '\t\t\t\t\t<span\n'
#  '\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\tdata-control-name="plug-type1-cdm-counter"\n'
#  '\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\tdata-path=".plug-type1-cdm"\n'
#  '\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t</span>\t\t\t\t\t\t\t\t  \n'
#  '\t\t\t\t\t</label>\n'
#  '\t\t\t\t </li>\n'
#  '\n'
#  '\t\t\t\t <li>\n'
#  '\t\t\t\t <input data-path=".plug-type2" id="plug-type2" type="checkbox" />\n'
#  '\t\t\t\t\t<label for="plug-type2">Type 2\n'
#  '\t\t\t\t\t<span\n'
#  '\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\tdata-control-name="plug-type2-counter"\n'
#  '\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\tdata-path=".plug-type2"\n'
#  '\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t</span>\t\t\t\t\t\t\t\t  \n'
#  '\t\t\t\t\t</label>\n'
#  '\t\t\t\t </li>\t\t\t\t \n'
#  ' \n'
#  '\t\t\t\t <li>\n'
#  '\t\t\t\t <input data-path=".plug-type2-ccs" id="plug-type2-ccs" '
#  'type="checkbox" />\n'
#  '\t\t\t\t\t<label for="plug-type2-ccs">Type 2 CCS\n'
#  '\t\t\t\t\t<span\n'
#  '\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\tdata-control-name="plug-type2-ccs-counter"\n'
#  '\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\tdata-path=".plug-type2-ccs"\n'
#  '\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t</span>\t\t\t\t\t\t\t\t  \n'
#  '\t\t\t\t\t</label>\n'
#  '\t\t\t\t </li>\t\t\t\n'
#  '\n'
#  '\t\t\t\t <li>\n'
#  '\t\t\t\t <input data-path=".plug-type2-cdm" id="plug-type2-cdm" '
#  'type="checkbox" />\n'
#  '\t\t\t\t\t<label for="plug-type2-cdm">Type 2 CHAdeMO\n'
#  '\t\t\t\t\t<span\n'
#  '\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\tdata-control-name="plug-type2-cdm-counter"\n'
#  '\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\tdata-path=".plug-type2-cdm"\n'
#  '\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t</span>\t\t\t\t\t\t\t\t  \n'
#  '\t\t\t\t\t</label>\n'
#  '\t\t\t\t </li>\t\n'
#  '\t\t\t\t \n'
#  '\t\t\t</ul>\n'
#  '\t\t\t</div>\n'
#  '\n'
#  '\t\t<!-- size dropdown -->\n'
#  '\t\t\t<div \n'
#  '\t\t\tclass="jplist-checkbox-dropdown"\n'
#  '\t\t\tdata-control-type="checkbox-dropdown" \n'
#  '\t\t\tdata-control-name="size-checkbox-dropdown" \n'
#  '\t\t\tdata-control-action="filter"\n'
#  '\t\t\tdata-no-selected-text="Segment"\n'
#  '\t\t\tdata-one-item-text="{selected}"\n'
#  '\t\t\tdata-many-items-text="{num} selected">\n'
#  '\t\t\t\t<ul>\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".size-a" id="size-a" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="size-a">A - Mini\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="size-a-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".size-a"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".size-b" id="size-b" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="size-b">B - Small\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="size-b-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".size-b"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".size-c" id="size-c" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="size-c">C - Medium\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="size-c-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".size-c"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>\n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".size-d" id="size-d" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="size-d">D - Large\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="size-d-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".size-d"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
#  '\t\t\t\t\t\tdata-type="path">\n'
#  '\t\t\t\t\t\t</span>          \n'
#  '\t\t\t\t\t\t</label>\n'
#  '\t\t\t\t\t</li>  \n'
#  '\n'
#  '\t\t\t\t\t<li>\n'
#  '\t\t\t\t\t\t<input data-path=".size-e" id="size-e" type="checkbox"/>\n'
#  '\t\t\t\t\t\t<label for="size-e">E - Executive\n'
#  '\t\t\t\t\t\t<span\n'
#  '\t\t\t\t\t\tdata-control-type="counter"\n'
#  '\t\t\t\t\t\tdata-control-action="counter"\n'
#  '\t\t\t\t\t\tdata-control-name="size-e-counter"\n'
#  '\t\t\t\t\t\tdata-format="({count})"\n'
#  '\t\t\t\t\t\tdata-path=".size-e"\n'
#  '\t\t\t\t\t\tdata-mode="filter"\n'
# ...
#  'C424.94,130.974 424.958,131.058 424.958,131.147 C424.958,131.058 '
#  '424.94,130.974 424.913,130.894 Z M424.901,150.525 C424.935,150.417 '
#  '424.958,150.304 424.958,150.185 L424.958,150.185 C424.958,150.304 '
#  '424.935,150.417 424.901,150.525 Z M302.993,171.718 C294.945,163.67 '
#  '290.005,152.804 290.005,140.842 C290.005,124.569 299.14,110.318 '
#  '312.815,102.443 C319.978,98.318 328.387,95.943 337.381,95.943 '
#  'C337.832,95.943 338.285,95.952 338.739,95.966 C342.893,96.077 346.914,96.692 '
#  '350.734,97.754 C350.902,97.801 353.529,98.769 354.477,99.21 C354.544,99.241 '
#  '354.608,99.277 354.669,99.316 C354.505,99.057 354.267,98.845 353.977,98.71 '
#  'C353.028,98.269 350.402,97.302 350.234,97.255 C346.414,96.193 342.393,95.578 '
#  '338.239,95.467 C337.785,95.453 337.331,95.444 336.881,95.444 C327.887,95.444 '
#  '319.478,97.819 312.315,101.944 C298.64,109.819 289.505,124.07 '
#  '289.505,140.343 C289.505,153.569 295.539,165.459 305.141,173.676 '
#  'C304.403,173.044 303.687,172.392 302.993,171.718 Z M424.159,130.348 '
#  'L389.587,130.348 C389.536,130.348 389.49,130.33 389.442,130.319 '
#  'C389.442,130.319 389.442,130.319 389.443,130.319 C389.511,130.619 '
#  '389.767,130.848 390.088,130.848 L424.66,130.848 C424.749,130.848 '
#  '424.833,130.866 424.913,130.893 C424.807,130.577 424.511,130.348 '
#  '424.159,130.348 Z M424.944,161.231 C424.876,160.846 424.542,160.552 '
#  '424.137,160.552 L390.353,160.552 C390.084,160.552 389.836,160.474 '
#  '389.621,160.346 C389.621,160.346 389.621,160.346 389.621,160.347 '
#  'C389.872,160.768 390.327,161.054 390.853,161.054 L424.638,161.054 '
#  'C424.734,161.054 424.824,161.074 424.91,161.103 C424.923,161.144 '
#  '424.935,161.187 424.944,161.231 Z M433.414,183.978 L433.414,97.707 '
#  'C433.414,96.733 434.204,95.944 435.178,95.944 L455.351,95.944 '
#  'C467.643,95.944 478.78,100.822 486.887,108.792 C478.74,100.526 '
#  '467.397,95.443 454.85,95.443 L434.677,95.443 C433.703,95.443 432.913,96.233 '
#  '432.913,97.207 L432.913,183.478 C432.913,184.093 433.229,184.633 '
#  '433.706,184.949 C433.523,184.67 433.414,184.337 433.414,183.978 Z '
#  'M433.956,185.084 C433.989,185.099 434.024,185.111 434.058,185.124 '
#  'C434.024,185.11 433.989,185.099 433.956,185.084 Z M424.803,96.466 '
#  'C424.819,96.501 424.831,96.537 424.844,96.572 C424.83,96.537 424.818,96.501 '
#  '424.803,96.466 Z M363.668,185.201 C363.763,185.226 363.861,185.241 '
#  '363.964,185.241 C363.861,185.241 363.764,185.225 363.668,185.201 Z '
#  'M363.378,185.087 C363.283,184.912 363.224,184.713 363.224,184.5 '
#  'L363.224,98.07 C363.224,96.895 364.176,95.943 365.351,95.943 L423.724,95.943 '
#  'C424.075,95.943 424.4,96.049 424.673,96.228 C424.674,96.229 424.675,96.231 '
#  '424.676,96.233 C424.367,95.758 423.833,95.443 423.224,95.443 L364.851,95.443 '
#  'C363.676,95.443 362.724,96.395 362.724,97.57 L362.724,183.999 '
#  'C362.724,184.571 363.112,185.047 363.638,185.191 C363.547,185.165 '
#  '363.46,185.131 363.378,185.087 Z M354.862,99.757 C354.878,99.816 '
#  '354.893,99.876 354.902,99.938 C354.892,99.877 354.878,99.817 354.862,99.757 '
#  'Z M388.914,129.674 C388.914,129.76 388.933,129.84 388.963,129.914 '
#  'C388.933,129.84 388.914,129.76 388.914,129.674 Z M389.159,121.766 '
#  'C389.056,121.919 388.981,122.093 388.943,122.28 C388.981,122.093 '
#  '389.056,121.919 389.159,121.766 Z M15.165,173.042 C14.893,172.799 '
#  '14.624,172.554 14.358,172.305 C14.623,172.553 14.892,172.799 15.165,173.042 '
#  'Z M61.835,97.912 C61.867,97.965 61.895,98.02 61.921,98.077 C61.896,98.02 '
#  '61.867,97.966 61.835,97.912 Z M13.523,171.504 C5.602,163.479 0.751,152.698 '
#  '0.751,140.842 C0.751,116.045 21.962,95.943 48.127,95.943 C52.764,95.943 '
#  '57.245,96.576 61.48,97.754 C61.608,97.789 61.725,97.845 61.835,97.911 '
#  'C61.646,97.598 61.349,97.356 60.979,97.253 C56.744,96.075 52.263,95.442 '
#  '47.626,95.442 C21.461,95.442 0.25,115.544 0.25,140.341 C0.25,152.839 '
#  '5.64,164.142 14.334,172.282 C14.061,172.027 13.79,171.767 13.523,171.504 Z '
#  'M61.934,98.108 C61.955,98.158 61.974,98.209 61.99,98.261 C61.974,98.209 '
#  '61.955,98.158 61.934,98.108 Z M62.036,98.464 C62.03,98.424 62.02,98.385 '
#  '62.01,98.346 C62.02,98.385 62.03,98.423 62.036,98.464 Z M62.054,125.442 '
#  'C62.054,125.8 61.846,126.077 61.57,126.208 C61.847,126.077 62.054,125.8 '
#  '62.054,125.442 L62.054,125.442 Z M143.612,184.466 C143.414,184.337 '
#  '143.223,184.197 143.046,184.042 C143.223,184.197 143.413,184.337 '
#  '143.612,184.466 Z M144.517,184.936 C144.448,184.909 144.383,184.877 '
#  '144.316,184.848 C144.383,184.877 144.448,184.909 144.517,184.936 Z '
#  'M134.479,97.426 C134.467,97.361 134.448,97.3 134.431,97.237 C134.448,97.299 '
#  '134.467,97.362 134.479,97.426 Z M143.803,184.586 C143.883,184.633 '
#  '143.964,184.678 144.046,184.72 C143.964,184.678 143.883,184.633 '
#  '143.803,184.586 Z M70.699,184.843 C70.756,184.884 70.818,184.917 '
#  '70.879,184.952 C70.818,184.917 70.756,184.883 70.699,184.843 Z '
#  'M107.333,184.992 L107.333,154.85 C107.333,154.399 107.074,154.013 '
#  '106.699,153.82 C106.781,153.979 106.832,154.158 106.832,154.35 '
#  'L106.832,184.491 C106.832,184.83 107.059,185.113 107.367,185.206 '
#  'C107.347,185.138 107.333,185.066 107.333,184.992 Z M145.576,185.212 '
#  'C145.633,185.22 145.69,185.229 145.748,185.236 C145.689,185.229 '
#  '145.633,185.22 145.576,185.212 Z M143.036,184.034 C141.885,182.695 '
#  '141.439,180.767 142.157,178.921 L173.993,97.133 L173.998,95.333 '
#  'L141.657,178.42 C140.842,180.514 141.526,182.709 143.036,184.034 Z '
#  'M218.626,184.931 C218.43,184.64 218.316,184.29 218.316,183.913 '
#  'L218.316,98.276 C218.316,96.988 219.36,95.943 220.649,95.943 L243.897,95.943 '
#  'C257.102,95.943 267.165,98.649 273.985,105.463 C267.161,98.275 '
#  '256.925,95.442 243.397,95.442 L220.149,95.442 C218.861,95.442 217.816,96.486 '
#  '217.816,97.775 L217.816,183.411 C217.816,184.045 218.138,184.602 '
#  '218.628,184.931 C218.627,184.931 218.626,184.931 218.626,184.931 Z '
#  'M145.178,185.135 C145.119,185.121 145.06,185.109 145.002,185.093 '
#  'C145.06,185.109 145.119,185.122 145.178,185.135 Z M255.348,132.238 '
#  'C255.348,129.734 254.272,127.488 252.566,125.916 C252.566,125.916 '
#  '252.565,125.915 252.565,125.915 C253.978,127.448 254.848,129.489 '
#  '254.848,131.738 C254.848,136.49 250.996,140.342 246.244,140.342 '
#  'L245.506,140.342 L245.506,140.342 L246.006,140.342 L246.006,140.842 '
#  'L246.744,140.842 C251.496,140.842 255.348,136.99 255.348,132.238 Z '
#  'M71.194,185.102 C71.136,185.08 71.079,185.057 71.023,185.031 C71.079,185.057 '
#  '71.136,185.08 71.194,185.102 Z M62.003,154.946 C61.819,154.426 '
#  '61.151,154.193 60.682,154.58 C57.184,157.466 52.618,159.218 47.627,159.218 '
#  'C42.036,159.218 36.979,157.021 33.358,153.493 C33.359,153.493 33.359,153.494 '
#  '33.36,153.495 C37.007,157.315 42.276,159.719 48.127,159.719 C53.119,159.719 '
#  '57.684,157.967 61.182,155.081 C61.433,154.872 61.741,154.849 62.003,154.946 '
#  'Z M71.547,185.202 C71.499,185.193 71.453,185.179 71.405,185.167 '
#  'C71.452,185.18 71.499,185.193 71.547,185.202 Z M97.217,96.827 C97.259,96.91 '
#  '97.296,96.995 97.329,97.083 C97.297,96.994 97.259,96.91 97.217,96.827 Z '
#  'M97.445,97.489 C97.432,97.42 97.412,97.354 97.393,97.287 C97.411,97.354 '
#  '97.432,97.42 97.445,97.489 Z M70.3,183.608 L70.3,96.8 C70.3,96.327 '
#  '70.684,95.943 71.157,95.943 L95.492,95.943 C96.054,95.943 96.568,96.135 '
#  '96.985,96.449 C97.051,96.537 97.109,96.632 97.164,96.729 C96.736,95.965 '
#  '95.929,95.443 94.991,95.443 L70.657,95.443 C70.184,95.443 69.8,95.827 '
#  '69.8,96.3 L69.8,183.108 C69.8,183.825 70.157,184.456 70.699,184.842 '
#  'C70.45,184.493 70.3,184.069 70.3,183.608 Z" id="Shape" '
#  'fill="#F1F1F1"></path>\n'
#  '\t\t\t\t\t\t\t\t\t\t\t\t\t</g>\n'
#  '\t\t\t\t\t\t\t\t\t\t\t\t\t<path d="M233.96,242.728 C231.32532,242.728 '
#  '228.937677,242.139006 226.797,240.961 C224.656323,239.782994 '
#  '222.984339,238.16801 221.781,236.116 C220.577661,234.06399 '
#  '219.976,231.758679 219.976,229.2 C219.976,226.641321 220.577661,224.33601 '
#  '221.781,222.284 C222.984339,220.23199 224.656323,218.617006 226.797,217.439 '
#  'C228.937677,216.260994 231.32532,215.672 233.96,215.672 C236.59468,215.672 '
#  '238.969656,216.254661 241.085,217.42 C243.200344,218.585339 '
#  '244.865994,220.200323 246.082,222.265 C247.298006,224.329677 '
#  '247.906,226.641321 247.906,229.2 C247.906,231.758679 247.298006,234.070323 '
#  '246.082,236.135 C244.865994,238.199677 243.200344,239.814661 241.085,240.98 '
#  'C238.969656,242.145339 236.59468,242.728 233.96,242.728 Z M233.96,240.22 '
#  'C236.062677,240.22 237.962658,239.745005 239.66,238.795 '
#  'C241.357342,237.844995 242.687329,236.527675 243.65,234.843 '
#  'C244.612671,233.158325 245.094,231.277344 245.094,229.2 C245.094,227.122656 '
#  '244.612671,225.241675 243.65,223.557 C242.687329,221.872325 '
#  '241.357342,220.555005 239.66,219.605 C237.962658,218.654995 '
#  '236.062677,218.18 233.96,218.18 C231.857323,218.18 229.951009,218.654995 '
#  '228.241,219.605 C226.530991,220.555005 225.188338,221.872325 224.213,223.557 '
#  'C223.237662,225.241675 222.75,227.122656 222.75,229.2 C222.75,231.277344 '
#  '223.237662,233.158325 224.213,234.843 C225.188338,236.527675 '
#  '226.530991,237.844995 228.241,238.795 C229.951009,239.745005 '
#  '231.857323,240.22 233.96,240.22 Z M257.026,218.332 L257.026,228.782 '
#  'L270.782,228.782 L270.782,231.214 L257.026,231.214 L257.026,242.5 '
#  'L254.214,242.5 L254.214,215.9 L272.454,215.9 L272.454,218.332 '
#  'L257.026,218.332 Z M281.08,218.332 L281.08,228.782 L294.836,228.782 '
#  'L294.836,231.214 L281.08,231.214 L281.08,242.5 L278.268,242.5 L278.268,215.9 '
#  'L296.508,215.9 L296.508,218.332 L281.08,218.332 Z M302.322,215.9 '
#  'L305.134,215.9 L305.134,242.5 L302.322,242.5 L302.322,215.9 Z '
#  'M325.35,242.728 C322.71532,242.728 320.340344,242.145339 318.225,240.98 '
#  'C316.109656,239.814661 314.450339,238.199677 313.247,236.135 '
#  'C312.043661,234.070323 311.442,231.758679 311.442,229.2 C311.442,226.641321 '
#  '312.043661,224.329677 313.247,222.265 C314.450339,220.200323 '
#  '316.115989,218.585339 318.244,217.42 C320.372011,216.254661 '
#  '322.75332,215.672 325.388,215.672 C327.36401,215.672 329.187992,216.00133 '
#  '330.86,216.66 C332.532008,217.31867 333.950661,218.281327 335.116,219.548 '
#  'L333.33,221.334 C331.252656,219.231323 328.630682,218.18 325.464,218.18 '
#  'C323.361323,218.18 321.448675,218.661329 319.726,219.624 '
#  'C318.003325,220.586671 316.654338,221.903992 315.679,223.576 '
#  'C314.703662,225.248008 314.216,227.122656 314.216,229.2 C314.216,231.277344 '
#  '314.703662,233.151992 315.679,234.824 C316.654338,236.496008 '
#  '318.003325,237.813329 319.726,238.776 C321.448675,239.738671 '
#  '323.361323,240.22 325.464,240.22 C328.656016,240.22 331.27799,239.156011 '
#  '333.33,237.028 L335.116,238.814 C333.950661,240.080673 332.525675,241.049663 '
#  '330.841,241.721 C329.156325,242.392337 327.32601,242.728 325.35,242.728 Z '
#  'M341.12,215.9 L343.932,215.9 L343.932,242.5 L341.12,242.5 L341.12,215.9 Z '
#  'M369.278,235.394 L354.458,235.394 L351.266,242.5 L348.34,242.5 L360.5,215.9 '
#  'L363.274,215.9 L375.434,242.5 L372.47,242.5 L369.278,235.394 Z '
#  'M368.252,233.114 L361.868,218.826 L355.484,233.114 L368.252,233.114 Z '
#  'M379.842,215.9 L382.654,215.9 L382.654,240.068 L397.55,240.068 L397.55,242.5 '
#  'L379.842,242.5 L379.842,215.9 Z M412.18,215.9 L423.01,215.9 '
#  'C425.822014,215.9 428.304656,216.463661 430.458,217.591 '
#  'C432.611344,218.718339 434.283327,220.28899 435.474,222.303 '
#  'C436.664673,224.31701 437.26,226.615987 437.26,229.2 C437.26,231.784013 '
#  '436.664673,234.08299 435.474,236.097 C434.283327,238.11101 '
#  '432.611344,239.681661 430.458,240.809 C428.304656,241.936339 '
#  '425.822014,242.5 423.01,242.5 L412.18,242.5 L412.18,215.9 Z M422.858,240.068 '
#  'C425.188678,240.068 427.227991,239.605671 428.976,238.681 '
#  'C430.724009,237.756329 432.079329,236.477008 433.042,234.843 '
#  'C434.004671,233.208992 434.486,231.328011 434.486,229.2 C434.486,227.071989 '
#  '434.004671,225.191008 433.042,223.557 C432.079329,221.922992 '
#  '430.724009,220.643671 428.976,219.719 C427.227991,218.794329 '
#  '425.188678,218.332 422.858,218.332 L414.992,218.332 L414.992,240.068 '
#  'L422.858,240.068 Z M459.87,235.394 L445.05,235.394 L441.858,242.5 '
#  'L438.932,242.5 L451.092,215.9 L453.866,215.9 L466.026,242.5 L463.062,242.5 '
#  'L459.87,235.394 Z M458.844,233.114 L452.46,218.826 L446.076,233.114 '
#  'L458.844,233.114 Z M474.272,218.332 L464.924,218.332 L464.924,215.9 '
#  'L486.432,215.9 L486.432,218.332 L477.084,218.332 L477.084,242.5 '
#  'L474.272,242.5 L474.272,218.332 Z M506.268,235.394 L491.448,235.394 '
#  'L488.256,242.5 L485.33,242.5 L497.49,215.9 L500.264,215.9 L512.424,242.5 '
#  'L509.46,242.5 L506.268,235.394 Z M505.242,233.114 L498.858,218.826 '
#  'L492.474,233.114 L505.242,233.114 Z M536.744,215.9 C540.138684,215.9 '
#  '542.798657,216.710659 544.724,218.332 C546.649343,219.953341 '
#  '547.612,222.182652 547.612,225.02 C547.612,227.857348 546.649343,230.080325 '
#  '544.724,231.689 C542.798657,233.297675 540.138684,234.102 536.744,234.102 '
#  'L529.6,234.102 L529.6,242.5 L526.788,242.5 L526.788,215.9 L536.744,215.9 Z '
#  'M536.668,231.632 C539.30268,231.632 541.31666,231.055672 542.71,229.903 '
#  'C544.10334,228.750328 544.8,227.122677 544.8,225.02 C544.8,222.866656 '
#  '544.10334,221.213672 542.71,220.061 C541.31666,218.908328 539.30268,218.332 '
#  '536.668,218.332 L529.6,218.332 L529.6,231.632 L536.668,231.632 Z '
#  'M569.044,235.394 L554.224,235.394 L551.032,242.5 L548.106,242.5 '
#  'L560.266,215.9 L563.04,215.9 L575.2,242.5 L572.236,242.5 L569.044,235.394 Z '
#  'M568.018,233.114 L561.634,218.826 L555.25,233.114 L568.018,233.114 Z '
#  'M597.772,242.5 L591.692,233.95 C591.007997,234.026 590.29867,234.064 '
#  '589.564,234.064 L582.42,234.064 L582.42,242.5 L579.608,242.5 L579.608,215.9 '
#  'L589.564,215.9 C592.958684,215.9 595.618657,216.710659 597.544,218.332 '
#  'C599.469343,219.953341 600.432,222.182652 600.432,225.02 C600.432,227.097344 '
#  '599.906339,228.85166 598.855,230.283 C597.803661,231.71434 '
#  '596.302676,232.746664 594.352,233.38 L600.85,242.5 L597.772,242.5 Z '
#  'M589.488,231.67 C592.12268,231.67 594.13666,231.087339 595.53,229.922 '
#  'C596.92334,228.756661 597.62,227.122677 597.62,225.02 C597.62,222.866656 '
#  '596.92334,221.213672 595.53,220.061 C594.13666,218.908328 592.12268,218.332 '
#  '589.488,218.332 L582.42,218.332 L582.42,231.67 L589.488,231.67 Z '
#  'M611.87,218.332 L602.522,218.332 L602.522,215.9 L624.03,215.9 '
#  'L624.03,218.332 L614.682,218.332 L614.682,242.5 L611.87,242.5 '
#  'L611.87,218.332 Z M650.744,215.9 L650.744,242.5 L648.426,242.5 '
#  'L631.326,220.916 L631.326,242.5 L628.514,242.5 L628.514,215.9 L630.832,215.9 '
#  'L647.97,237.484 L647.97,215.9 L650.744,215.9 Z M678.218,240.068 '
#  'L678.218,242.5 L659.408,242.5 L659.408,215.9 L677.648,215.9 L677.648,218.332 '
#  'L662.22,218.332 L662.22,227.794 L675.976,227.794 L675.976,230.188 '
#  'L662.22,230.188 L662.22,240.068 L678.218,240.068 Z M702.994,242.5 '
#  'L696.914,233.95 C696.229997,234.026 695.52067,234.064 694.786,234.064 '
#  'L687.642,234.064 L687.642,242.5 L684.83,242.5 L684.83,215.9 L694.786,215.9 '
#  'C698.180684,215.9 700.840657,216.710659 702.766,218.332 '
#  'C704.691343,219.953341 705.654,222.182652 705.654,225.02 C705.654,227.097344 '
#  '705.128339,228.85166 704.077,230.283 C703.025661,231.71434 '
#  '701.524676,232.746664 699.574,233.38 L706.072,242.5 L702.994,242.5 Z '
#  'M694.71,231.67 C697.34468,231.67 699.35866,231.087339 700.752,229.922 '
#  'C702.14534,228.756661 702.842,227.122677 702.842,225.02 C702.842,222.866656 '
#  '702.14534,221.213672 700.752,220.061 C699.35866,218.908328 697.34468,218.332 '
#  '694.71,218.332 L687.642,218.332 L687.642,231.67 L694.71,231.67 Z" '
#  'id="OFFICIALDATAPARTNER" stroke="#DADADA" fill="#FFFFFF"></path>\n'
#  '\t\t\t\t\t\t\t\t\t\t\t</g>\n'
#  '\t\t\t\t\t\t\t\t\t</g>\n'
#  '\t\t\t\t\t\t\t</g>\n'
#  '\t\t\t\t\t</svg>\n'
#  '\t\t\t\t</a>\n'
#  '\t\t\t</div>\n'
#  '\t\t\t\n'
#  '\t\t</section>\n'
#  '\n'
#  '\t<div class="footer-bot-row">\n'
#  '\t\t&copy;2022 EV Database - v4.3\t\t\t\n'
#  '\t</div>\t\n'
#  '</footer>\t\r\n'
#  '\t</body>\r\n'
#  '</html>')

# %%
# Creating an empty list to hold the data

ev_data=[]

# Creating a variable to hold the scraped data

html = BeautifulSoup(data.text, 'html.parser')

#creating a variable to allow structuring of data using html containers and class names

evcars = html.select('div.list-item')

# iterating through evcars to scrape the desired data using class names to identify relevant data

for evcar in evcars:
    
    make = evcar.select('.title')[0].get_text()
    model = evcar.select('.model')[0].get_text()
    battery_Kwh = evcar.select('.battery')[0].get_text()
    acceleration = evcar.select('.acceleration')[0].get_text()
    top_speed = evcar.select('.topspeed')[0].get_text()
    erange_real = evcar.select('.erange_real')[0].get_text()
    efficiency = evcar.select('.efficiency')[0].get_text()
    price_in_de = evcar.select('.country_de')[0].get_text()
    
    #adding the data to ev_data
    
    ev_data.append({"Make": make, "Model": model, "Battery_(Kwh)": battery_Kwh, "Acceleration_in_Secs_(1-100)": acceleration,
                    "Top_Speed_(km/h)": top_speed, "Range_(km)": erange_real, "Efficiency_(Wh/km)": efficiency, "Price_in_Germany (€)": price_in_de})
    
# Converting the list of dictionaries in to a Pandas DataFrame    

ev_df = pd.DataFrame(ev_data)


# Print the head of the dataframe to check structure and check dataframe shape

print(ev_df.head())

print(ev_df.shape)

# Check the DataFrame info

print(ev_df.info())
# Out:
#                                   Make                          Model  \
# 0  Tesla Model 3 Long Range Dual Motor  Model 3 Long Range Dual Motor
# 1                      BMW i4 eDrive40                    i4 eDrive40
# 2                       Tesla Model 3                        Model 3
# 3                Dacia Spring Electric                Spring Electric
# 4                           Kia EV6 GT                         EV6 GT
#
#   Battery_(Kwh) Acceleration_in_Secs_(1-100) Top_Speed_(km/h) Range_(km)  \
# 0            75                      4.4 sec         233 km/h     485 km
# 1          80.7                      5.7 sec         190 km/h     470 km
# 2          57.5                      6.1 sec         225 km/h     380 km
# 3          26.8                     15.0 sec         125 km/h     170 km
# 4          72.5                      3.5 sec         260 km/h     360 km
#
#   Efficiency_(Wh/km) Price_in_Germany (€)
# 0          155 Wh/km              €60,260
# 1          172 Wh/km              €58,300
# 2          151 Wh/km              €48,260
# 3          158 Wh/km              €20,490
# 4          201 Wh/km              €65,990
# (228, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Make                          228 non-null    object
#  1   Model                         228 non-null    object
#  2   Battery_(Kwh)                 228 non-null    object
#  3   Acceleration_in_Secs_(1-100)  228 non-null    object
#  4   Top_Speed_(km/h)              228 non-null    object
#  5   Range_(km)                    228 non-null    object
#  6   Efficiency_(Wh/km)            228 non-null    object
#  7   Price_in_Germany (€)          228 non-null    object
# dtypes: object(8)
# memory usage: 14.4+ KB
# None

# %% [markdown]
# # Data Cleaning

# %%
# Stripping out the additional text in the Make column that already exists in the Model column

ev_df['Make']=[a.replace(b, '').strip() for a,b in zip(ev_df['Make'],ev_df['Model'])]

# Creating a new column concatenating Make and Model to provide a separate column with full description

ev_df['Make/Model'] = ev_df['Make'] + " " + ev_df['Model']

# Stripping out extraneous text from dataframe columns to facilitate analysis later

ev_df['Acceleration_in_Secs_(1-100)'] = ev_df['Acceleration_in_Secs_(1-100)'].str.strip("sec")

ev_df['Top_Speed_(km/h)'] = ev_df['Top_Speed_(km/h)'].str.strip(" km/h")

ev_df['Range_(km)'] = ev_df['Range_(km)'].str.strip(" km")

ev_df['Efficiency_(Wh/km)'] = ev_df['Efficiency_(Wh/km)'].str.strip(" Wh/km")

ev_df['Price_in_Germany (€)'] = ev_df['Price_in_Germany (€)'].str.replace("€","")

ev_df['Price_in_Germany (€)'] = ev_df['Price_in_Germany (€)'].str.replace(",","")

ev_df['Price_in_Germany (€)'] = ev_df['Price_in_Germany (€)'].str.strip("*")

ev_df['Price_in_Germany (€)'] = ev_df['Price_in_Germany (€)'].str.strip("N/A")

print(ev_df.head())  

print(ev_df.info())
# Out:
#     Make                          Model Battery_(Kwh)  \
# 0  Tesla  Model 3 Long Range Dual Motor            75
# 1    BMW                    i4 eDrive40          80.7
# 2  Tesla                       Model 3           57.5
# 3  Dacia                Spring Electric          26.8
# 4    Kia                         EV6 GT          72.5
#
#   Acceleration_in_Secs_(1-100) Top_Speed_(km/h) Range_(km) Efficiency_(Wh/km)  \
# 0                         4.4               233        485                155
# 1                         5.7               190        470                172
# 2                         6.1               225        380                151
# 3                        15.0               125        170                158
# 4                         3.5               260        360                201
#
#   Price_in_Germany (€)                           Make/Model
# 0                60260  Tesla Model 3 Long Range Dual Motor
# 1                58300                      BMW i4 eDrive40
# 2                48260                       Tesla Model 3
# 3                20490                Dacia Spring Electric
# 4                65990                           Kia EV6 GT
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Make                          228 non-null    object
#  1   Model                         228 non-null    object
#  2   Battery_(Kwh)                 228 non-null    object
#  3   Acceleration_in_Secs_(1-100)  228 non-null    object
#  4   Top_Speed_(km/h)              228 non-null    object
#  5   Range_(km)                    228 non-null    object
#  6   Efficiency_(Wh/km)            228 non-null    object
#  7   Price_in_Germany (€)          228 non-null    object
#  8   Make/Model                    228 non-null    object
# dtypes: object(9)
# memory usage: 16.2+ KB
# None

# %%
# converting objects to numeric values where possible to facilitate analysis later

cols = ev_df.columns

ev_df[cols]=ev_df[cols].apply(pd.to_numeric, errors='ignore')

print(ev_df.info())
print(ev_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Make                          228 non-null    object
#  1   Model                         228 non-null    object
#  2   Battery_(Kwh)                 228 non-null    float64
#  3   Acceleration_in_Secs_(1-100)  228 non-null    float64
#  4   Top_Speed_(km/h)              228 non-null    int64
#  5   Range_(km)                    228 non-null    int64
#  6   Efficiency_(Wh/km)            228 non-null    int64
#  7   Price_in_Germany (€)          214 non-null    float64
#  8   Make/Model                    228 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 16.2+ KB
# None
#     Make                          Model  Battery_(Kwh)  \
# 0  Tesla  Model 3 Long Range Dual Motor           75.0
# 1    BMW                    i4 eDrive40           80.7
# 2  Tesla                       Model 3            57.5
# 3  Dacia                Spring Electric           26.8
# 4    Kia                         EV6 GT           72.5
#
#    Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 0                           4.4               233         485
# 1                           5.7               190         470
# 2                           6.1               225         380
# 3                          15.0               125         170
# 4                           3.5               260         360
#
#    Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 0                 155               60260.0
# 1                 172               58300.0
# 2                 151               48260.0
# 3                 158               20490.0
# 4                 201               65990.0
#
#                             Make/Model
# 0  Tesla Model 3 Long Range Dual Motor
# 1                      BMW i4 eDrive40
# 2                       Tesla Model 3
# 3                Dacia Spring Electric
# 4                           Kia EV6 GT

# %%
# I can see from the dataframe info above that the Price column has a number of NaN values
# Firstly I will identify the rows with NaN values and identify the associated cars to check if I would like to keep any

bool_series = pd.isnull(ev_df['Price_in_Germany (€)'])
ev_df[bool_series]
# Out:
#            Make                          Model  Battery_(Kwh)  \
# 58        Seres                             3            52.0
# 93      Hyundai         IONIQ 5 Long Range 2WD           72.5
# 100  Volkswagen                       ID.4 Pro           77.0
# 102     Hyundai         IONIQ 5 Long Range AWD           72.5
# 117  Volkswagen          ID.3 Pure Performance           45.0
# 122          MG              MG5 EV Long Range           57.0
# 130         JAC                         iEV7s            39.0
# 159          MG    MG5 Electric Standard Range           46.0
# 195      Toyota        PROACE Shuttle L 75 kWh           65.0
# 205      Toyota        PROACE Shuttle M 75 kWh           65.0
# 208      Toyota        PROACE Shuttle L 50 kWh           45.0
# 213     Peugeot  e-Expert Combi Compact 50 kWh           45.0
# 218      Toyota        PROACE Shuttle M 50 kWh           45.0
# 219     Citroen        e-Jumpy Combi XS 50 kWh           45.0
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 58                            8.9               155         270
# 93                            7.4               185         390
# 100                          10.4               160         410
# 102                           5.2               185         385
# 117                           8.9               160         275
# 122                           7.7               185         340
# 130                          12.0               132         225
# 159                           8.5               185         260
# 195                          13.1               130         245
# 205                          13.1               130         245
# 208                          12.1               130         175
# 213                          12.1               130         180
# 218                          12.1               130         175
# 219                          12.1               130         180
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 58                  193                   NaN
# 93                  186                   NaN
# 100                 188                   NaN
# 102                 188                   NaN
# 117                 164                   NaN
# 122                 168                   NaN
# 130                 173                   NaN
# 159                 177                   NaN
# 195                 265                   NaN
# 205                 265                   NaN
# 208                 257                   NaN
# 213                 250                   NaN
# 218                 257                   NaN
# 219                 250                   NaN
#
#                                 Make/Model
# 58                                Seres 3
# 93          Hyundai IONIQ 5 Long Range 2WD
# 100                    Volkswagen ID.4 Pro
# 102         Hyundai IONIQ 5 Long Range AWD
# 117       Volkswagen ID.3 Pure Performance
# 122                   MG MG5 EV Long Range
# 130                             JAC iEV7s
# 159         MG MG5 Electric Standard Range
# 195         Toyota PROACE Shuttle L 75 kWh
# 205         Toyota PROACE Shuttle M 75 kWh
# 208         Toyota PROACE Shuttle L 50 kWh
# 213  Peugeot e-Expert Combi Compact 50 kWh
# 218         Toyota PROACE Shuttle M 50 kWh
# 219        Citroen e-Jumpy Combi XS 50 kWh

# %%
# Of the cars listed with NaN values in the cell above I would like to keep the Hyundai models.
# I will look up the correct prices for these cars and insert them in to the dataframe
# I know the two values I want to replace are at row indices 99 and 109 in the Price column
# Prices from https://www.kearys.ie/hyundai/new-cars/ioniq-5/

# First I will use the .at() method

ev_df.at[99, 'Price_in_Germany (€)'] = 53995

# For the second one I will use the .loc() method

ev_df.loc[109, 'Price_in_Germany (€)'] = 65495

#I will check the rows in the Price column with Nan values again

bool_series = pd.isnull(ev_df['Price_in_Germany (€)'])
ev_df[bool_series]
# Out:
#            Make                          Model  Battery_(Kwh)  \
# 58        Seres                             3            52.0
# 93      Hyundai         IONIQ 5 Long Range 2WD           72.5
# 100  Volkswagen                       ID.4 Pro           77.0
# 102     Hyundai         IONIQ 5 Long Range AWD           72.5
# 117  Volkswagen          ID.3 Pure Performance           45.0
# 122          MG              MG5 EV Long Range           57.0
# 130         JAC                         iEV7s            39.0
# 159          MG    MG5 Electric Standard Range           46.0
# 195      Toyota        PROACE Shuttle L 75 kWh           65.0
# 205      Toyota        PROACE Shuttle M 75 kWh           65.0
# 208      Toyota        PROACE Shuttle L 50 kWh           45.0
# 213     Peugeot  e-Expert Combi Compact 50 kWh           45.0
# 218      Toyota        PROACE Shuttle M 50 kWh           45.0
# 219     Citroen        e-Jumpy Combi XS 50 kWh           45.0
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 58                            8.9               155         270
# 93                            7.4               185         390
# 100                          10.4               160         410
# 102                           5.2               185         385
# 117                           8.9               160         275
# 122                           7.7               185         340
# 130                          12.0               132         225
# 159                           8.5               185         260
# 195                          13.1               130         245
# 205                          13.1               130         245
# 208                          12.1               130         175
# 213                          12.1               130         180
# 218                          12.1               130         175
# 219                          12.1               130         180
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 58                  193                   NaN
# 93                  186                   NaN
# 100                 188                   NaN
# 102                 188                   NaN
# 117                 164                   NaN
# 122                 168                   NaN
# 130                 173                   NaN
# 159                 177                   NaN
# 195                 265                   NaN
# 205                 265                   NaN
# 208                 257                   NaN
# 213                 250                   NaN
# 218                 257                   NaN
# 219                 250                   NaN
#
#                                 Make/Model
# 58                                Seres 3
# 93          Hyundai IONIQ 5 Long Range 2WD
# 100                    Volkswagen ID.4 Pro
# 102         Hyundai IONIQ 5 Long Range AWD
# 117       Volkswagen ID.3 Pure Performance
# 122                   MG MG5 EV Long Range
# 130                             JAC iEV7s
# 159         MG MG5 Electric Standard Range
# 195         Toyota PROACE Shuttle L 75 kWh
# 205         Toyota PROACE Shuttle M 75 kWh
# 208         Toyota PROACE Shuttle L 50 kWh
# 213  Peugeot e-Expert Combi Compact 50 kWh
# 218         Toyota PROACE Shuttle M 50 kWh
# 219        Citroen e-Jumpy Combi XS 50 kWh

# %%
# The two Hyundai cars now have the correct prices

ev_df[ev_df['Make'] == 'Hyundai']
# Out:
#         Make                       Model  Battery_(Kwh)  \
# 6    Hyundai      IONIQ 5 Long Range AWD           70.0
# 9    Hyundai              IONIQ Electric           38.3
# 17   Hyundai        Kona Electric 64 kWh           64.0
# 39   Hyundai      IONIQ 5 Long Range 2WD           70.0
# 75   Hyundai  IONIQ 5 Standard Range 2WD           54.0
# 81   Hyundai        Kona Electric 39 kWh           39.2
# 93   Hyundai      IONIQ 5 Long Range 2WD           72.5
# 102  Hyundai      IONIQ 5 Long Range AWD           72.5
# 165  Hyundai  IONIQ 5 Standard Range AWD           54.0
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 6                             5.2               185         370
# 9                             9.7               165         250
# 17                            7.9               167         395
# 39                            7.4               185         380
# 75                            8.5               185         295
# 81                            9.9               155         250
# 93                            7.4               185         390
# 102                           5.2               185         385
# 165                           6.1               185         290
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 6                   189               48900.0
# 9                   153               35350.0
# 17                  162               41850.0
# 39                  184               45100.0
# 75                  183               41900.0
# 81                  157               35650.0
# 93                  186                   NaN
# 102                 188                   NaN
# 165                 186               45700.0
#
#                              Make/Model
# 6        Hyundai IONIQ 5 Long Range AWD
# 9                Hyundai IONIQ Electric
# 17         Hyundai Kona Electric 64 kWh
# 39       Hyundai IONIQ 5 Long Range 2WD
# 75   Hyundai IONIQ 5 Standard Range 2WD
# 81         Hyundai Kona Electric 39 kWh
# 93       Hyundai IONIQ 5 Long Range 2WD
# 102      Hyundai IONIQ 5 Long Range AWD
# 165  Hyundai IONIQ 5 Standard Range AWD

# %%
# I will drop the rows with NaN values in Price

ev_df = ev_df.dropna(subset=['Price_in_Germany (€)'])


print(ev_df.info())
print(ev_df.head(20))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 227
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Make                          214 non-null    object
#  1   Model                         214 non-null    object
#  2   Battery_(Kwh)                 214 non-null    float64
#  3   Acceleration_in_Secs_(1-100)  214 non-null    float64
#  4   Top_Speed_(km/h)              214 non-null    int64
#  5   Range_(km)                    214 non-null    int64
#  6   Efficiency_(Wh/km)            214 non-null    int64
#  7   Price_in_Germany (€)          214 non-null    float64
#  8   Make/Model                    214 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 16.7+ KB
# None
#         Make                          Model  Battery_(Kwh)  \
# 0      Tesla  Model 3 Long Range Dual Motor           75.0
# 1        BMW                    i4 eDrive40           80.7
# 2      Tesla                       Model 3            57.5
# 3      Dacia                Spring Electric           26.8
# 4        Kia                         EV6 GT           72.5
# 5   Polestar        2 Long Range Dual Motor           75.0
# 6    Hyundai         IONIQ 5 Long Range AWD           70.0
# 7   Mercedes                       EQS 450+          107.8
# 8      Tesla  Model Y Long Range Dual Motor           75.0
# 9    Hyundai                 IONIQ Electric           38.3
# 10   Renault       Megane E-Tech EV60 220hp           60.0
# 11       BMW                    iX xDrive50          105.2
# 12     Skoda                    Enyaq iV 80           77.0
# 13       Kia             EV6 Long Range 2WD           72.5
# 14    Nissan                    Ariya 87kWh           87.0
# 15       BMW                         i4 M50           80.7
# 16  Mercedes                        EQA 250           66.5
# 17   Hyundai           Kona Electric 64 kWh           64.0
# 18       BMW                      i3 120 Ah           37.9
# 19     Honda                             e            28.5
#
#     Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 0                            4.4               233         485
# 1                            5.7               190         470
# 2                            6.1               225         380
# 3                           15.0               125         170
# 4                            3.5               260         360
# 5                            4.7               205         395
# 6                            5.2               185         370
# 7                            6.2               210         640
# 8                            5.0               217         435
# 9                            9.7               165         250
# 10                           7.5               160         360
# 11                           4.6               200         505
# 12                           8.6               160         420
# 13                           7.3               185         400
# 14                           7.6               160         445
# 15                           3.9               225         435
# 16                           8.9               160         355
# 17                           7.9               167         395
# 18                           7.3               150         235
# 19                           9.0               145         170
#
#     Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 0                  155               60260.0
# 1                  172               58300.0
# 2                  151               48260.0
# 3                  158               20490.0
# 4                  201               65990.0
# 5                  190               50970.0
# 6                  189               48900.0
# 7                  168              106374.0
# 8                  172               59965.0
# 9                  153               35350.0
# 10                 167               41700.0
# 11                 208               98000.0
# 12                 183               44750.0
# 13                 181               48990.0
# 14                 196               55000.0
# 15                 186               69900.0
# 16                 187               47541.0
# 17                 162               41850.0
# 18                 161               39000.0
# 19                 168               33850.0
#
#                              Make/Model
# 0   Tesla Model 3 Long Range Dual Motor
# 1                       BMW i4 eDrive40
# 2                        Tesla Model 3
# 3                 Dacia Spring Electric
# 4                            Kia EV6 GT
# 5      Polestar 2 Long Range Dual Motor
# 6        Hyundai IONIQ 5 Long Range AWD
# 7                     Mercedes EQS 450+
# 8   Tesla Model Y Long Range Dual Motor
# 9                Hyundai IONIQ Electric
# 10     Renault Megane E-Tech EV60 220hp
# 11                      BMW iX xDrive50
# 12                    Skoda Enyaq iV 80
# 13               Kia EV6 Long Range 2WD
# 14                   Nissan Ariya 87kWh
# 15                           BMW i4 M50
# 16                     Mercedes EQA 250
# 17         Hyundai Kona Electric 64 kWh
# 18                        BMW i3 120 Ah
# 19                             Honda e

# %% [markdown]
# # Summary Data Analysis

# %%
# Summary analysis
import matplotlib.pyplot as plt
import seaborn as sns



print("The median battery capacity is "+  str(ev_df['Battery_(Kwh)'].median()) + "Kwh."'\n')

print("The car with the highest battery capacity is the "+ ev_df.loc[ev_df['Battery_(Kwh)'].idxmax(),'Make/Model'] + " at " + str(ev_df['Battery_(Kwh)'].max()) + "Kwh."'\n')

print("The car with the lowest battery capacity is the "+ ev_df.loc[ev_df['Battery_(Kwh)'].idxmin(),'Make/Model'] + " at " + str(ev_df['Battery_(Kwh)'].min()) + "Kwh."'\n')

print("The median range is " + str(ev_df['Range_(km)'].median()) +"km"'\n')

print("The car with the longest range is the "+ ev_df.loc[ev_df['Range_(km)'].idxmax(),'Make/Model'] + " at " + str(ev_df['Range_(km)'].max()) + "km."'\n')

print("The car with the shortest range is the "+ ev_df.loc[ev_df['Range_(km)'].idxmin(),'Make/Model'] + " at " + str(ev_df['Range_(km)'].min()) + "km."'\n')

print("The median energy efficiency is " + str(ev_df['Efficiency_(Wh/km)'].median()) +" Wh/km"'\n')

print("The most energy efficient car is the "+ ev_df.loc[ev_df['Efficiency_(Wh/km)'].idxmin(),'Make/Model'] + " at " + str(ev_df['Efficiency_(Wh/km)'].min()) + "Wh/km."'\n')

print("The least energy efficient car is the "+ ev_df.loc[ev_df['Efficiency_(Wh/km)'].idxmax(),'Make/Model'] + " at " + str(ev_df['Efficiency_(Wh/km)'].max()) + "Wh/km."'\n')

print("The median acceleration rate from 0 to 100 km/h is " + str(ev_df['Acceleration_in_Secs_(1-100)'].median()) + "sec"'\n')

print("The car with the fastest acceleration is the "+ ev_df.loc[ev_df['Acceleration_in_Secs_(1-100)'].idxmin(),'Make/Model'] + " at " + str(ev_df['Acceleration_in_Secs_(1-100)'].min()) + "secs."'\n')

print("The car with the slowest acceleration is the "+ ev_df.loc[ev_df['Acceleration_in_Secs_(1-100)'].idxmax(),'Make/Model'] + " at " + str(ev_df['Acceleration_in_Secs_(1-100)'].max()) + "secs."'\n')

print("The median top speed is " + str(ev_df['Top_Speed_(km/h)'].median()) + "km/h"'\n')

print("The car capable of the highest speed is the "+ ev_df.loc[ev_df['Top_Speed_(km/h)'].idxmax(),'Make/Model'] + " at " + str(ev_df['Top_Speed_(km/h)'].max()) + "km/h."'\n')

print("The car with the lowest maximum speed is the "+ ev_df.loc[ev_df['Top_Speed_(km/h)'].idxmin(),'Make/Model'] + " at " + str(ev_df['Top_Speed_(km/h)'].min()) + "km/h."'\n')

print("The median price for an electric car in Germany is €" + str(int(ev_df['Price_in_Germany (€)'].median())) + '\n')

print("The most expensive car is the "+ ev_df.loc[ev_df['Price_in_Germany (€)'].idxmax(),'Make/Model'] + " at €" + str(int(ev_df['Price_in_Germany (€)'].max()))+'\n')

print("The least expensive car is the "+ ev_df.loc[ev_df['Price_in_Germany (€)'].idxmin(),'Make/Model'] + " at €" + str(int(ev_df['Price_in_Germany (€)'].min()))+'\n')
# Out:
# The median battery capacity is 66.5Kwh.
#
# The car with the highest battery capacity is the Mercedes EQS 450+ at 107.8Kwh.
#
# The car with the lowest battery capacity is the Smart EQ forfour  at 16.7Kwh.
#
# The median range is 342.5km
#
# The car with the longest range is the Mercedes EQS 450+ at 640km.
#
# The car with the shortest range is the Smart EQ forfour  at 95km.
#
# The median energy efficiency is 190.0 Wh/km
#
# The most energy efficient car is the Lightyear One  at 104Wh/km.
#
# The least energy efficient car is the Mercedes EQV 300 Long at 295Wh/km.
#
# The median acceleration rate from 0 to 100 km/h is 7.9sec
#
# The car with the fastest acceleration is the Tesla Model S Plaid at 2.1secs.
#
# The car with the slowest acceleration is the Dacia Spring Electric at 15.0secs.
#
# The median top speed is 160.0km/h
#
# The car capable of the highest speed is the Tesla Model S Plaid at 322km/h.
#
# The car with the lowest maximum speed is the Dacia Spring Electric at 125km/h.
#
# The median price for an electric car in Germany is €52945
#
# The most expensive car is the Porsche Taycan Turbo S Cross Turismo at €187746
#
# The least expensive car is the Smart EQ fortwo coupe at €18460

# %%
#Checking for any correlation between Price and Acceleration
# This scatterplot shows that there is a moderate, positive correlation between Price and Acceleration (r = 0.58) 
# Range has been added as another vector 

sns.scatterplot(data=ev_df, x='Price_in_Germany (€)',y='Acceleration_in_Secs_(1-100)', size ='Range_(km)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Checking for any correlation between Price and Range with Efficiency as a further vector using hue
# The correlation between Price and Range is very similar to the Price/Acceleration correlation (r = 0.58)

sns.scatterplot(data=ev_df, x='Price_in_Germany (€)',y='Range_(km)', hue ='Efficiency_(Wh/km)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plotting out Efficiency by Manufacturer

g=sns.catplot(x='Make', y= 'Efficiency_(Wh/km)', data=ev_df, kind = 'box', height = 5, aspect=2)

g.set_xticklabels(rotation = 70, size =10)

g.fig.suptitle('Efficiency by Manufacturer')

plt.show()

# %%
# Plotting out Range by Manufacturer

g=sns.catplot(x='Make', y= 'Range_(km)', data=ev_df, kind = 'box', height = 5, aspect=2)

g.set_xticklabels(rotation = 70, size =10)

g.fig.suptitle('Range by Manufacturer')

plt.show()

# %%
# Checking for any correlation between Top Speed and Efficiency
# This plot doesn't indicate any strong correlation between Top Speed and Efficiency

sns.scatterplot(data=ev_df, x='Top_Speed_(km/h)',y='Efficiency_(Wh/km)', hue ='Price_in_Germany (€)')

plt.show()

# %%
#  Running a correlation heatmap to check for correlations between all dimensions of the data.

sns.heatmap(ev_df.corr(), annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There were some interesting findings in this plot to add to the ones we gleaned from the scatterplots above.
# The strongest correlations are between Top Speed and Acceleration (r = -0.88), Battery Capacity and
# Range (r = 0.86) and Acceleration and Range (r = -0.75).

# %% [markdown]
# Just as interesting were those combinations with very weak correlations.
# The Price you pay has very little to do with Fuel Efficiency (r = 0.11).
# Range is much more closely linked to Battery Capacity (r = 0.86) than it does with Fuel Efficiency (r = 0.38).

# %% [markdown]
# Now to move on to more specific analysis to find a suitable electric car for my own needs.

# %% [markdown]
# # Specific Data Analysis

# %%
# Checking  relevant values by Manufacturer

import numpy as np

# Grouping cars by make with Range, Battery Capacity and Price columns.

ev_df.groupby(['Make'])[['Range_(km)', 'Battery_(Kwh)','Efficiency_(Wh/km)', 'Price_in_Germany (€)']].mean().round(2)
# Out:
#             Range_(km)  Battery_(Kwh)  Efficiency_(Wh/km)  \
# Make
# Aiways          330.00          63.00              191.00
# Audi            358.33          75.49              211.73
# BMW             386.88          74.08              188.00
# CUPRA           355.00          59.50              167.25
# Citroen         212.50          51.67              244.17
# DS              260.00          45.00              173.00
# Dacia           170.00          26.80              158.00
# Fiat            208.75          33.30              159.50
# Ford            389.00          80.00              205.60
# Genesis         375.00          72.50              193.33
# Honda           170.00          28.50              168.00
# Hyundai         318.57          55.64              173.43
# Jaguar          380.00          84.70              223.00
# Kia             332.50          59.74              178.50
# Lexus           235.00          45.00              191.00
# Lightyear       575.00          60.00              104.00
# Lucid           566.67          91.67              161.33
# MG              325.00          60.86              186.80
# Mazda           170.00          30.00              176.00
# Mercedes        379.13          79.80              224.09
# Mini            185.00          28.90              156.00
# Nissan          360.00          70.33              192.83
# Opel            217.31          51.15              238.00
# Peugeot         221.15          52.08              237.85
# Polestar        401.67          72.33              180.00
# Porsche         416.11          80.88              194.78
# Renault         283.57          46.61              164.14
# Skoda           385.56          70.00              181.33
# Smart            96.67          16.70              173.00
# Sono            260.00          47.00              181.00
# SsangYong       290.00          56.00              193.00
# Subaru          375.00          71.40              190.00
# Tesla           475.00          81.94              172.44
# Toyota          268.33          60.47              234.17
# Volkswagen      368.46          66.79              180.85
# Volvo           332.50          71.00              213.50
#
#             Price_in_Germany (€)
# Make
# Aiways                  35993.00
# Audi                    71789.67
# BMW                     75936.88
# CUPRA                   38205.00
# Citroen                 49735.83
# DS                      39440.00
# Dacia                   20490.00
# Fiat                    27810.00
# Ford                    58665.00
# Genesis                 60126.67
# Honda                   35925.00
# Hyundai                 42064.29
# Jaguar                  77300.00
# Kia                     44877.50
# Lexus                   47550.00
# Lightyear              150000.00
# Lucid                  111666.67
# MG                      40890.00
# Mazda                   34490.00
# Mercedes                76674.30
# Mini                    32500.00
# Nissan                  48756.67
# Opel                    49595.23
# Peugeot                 49312.31
# Polestar                48655.00
# Porsche                127185.44
# Renault                 34337.14
# Skoda                   45744.44
# Smart                   19766.67
# Sono                    28500.00
# SsangYong               38990.00
# Subaru                  50000.00
# Tesla                   94223.33
# Toyota                  59218.33
# Volkswagen              42872.31
# Volvo                   51932.50

# %%
# I am interested in Price, Range and EFficiency so I will sort the dataframe by these values

ev_df.sort_values(['Range_(km)', 'Price_in_Germany (€)', 'Efficiency_(Wh/km)'], ascending = [False, False, True])
# Out:
#           Make                  Model  Battery_(Kwh)  \
# 7     Mercedes               EQS 450+          107.8
# 57       Lucid      Air Grand Touring          105.0
# 22    Mercedes         EQS 580 4MATIC          107.8
# 31       Tesla     Model S Long Range           95.0
# 32   Lightyear                   One            60.0
# ..         ...                    ...            ...
# 107       Fiat  500e Hatchback 24 kWh           21.3
# 73     Renault        Twingo Electric           21.3
# 143      Smart        EQ fortwo coupe           16.7
# 178      Smart       EQ fortwo cabrio           16.7
# 101      Smart            EQ forfour            16.7
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 7                             6.2               210         640
# 57                            3.2               270         630
# 22                            4.3               210         610
# 31                            3.2               250         585
# 32                           10.0               150         575
# ..                            ...               ...         ...
# 107                           9.5               135         135
# 73                           12.6               135         130
# 143                          11.6               130         100
# 178                          11.9               130          95
# 101                          12.7               130          95
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)                  Make/Model
# 7                   168              106374.0           Mercedes EQS 450+
# 57                  167              150000.0     Lucid Air Grand Touring
# 22                  177              135529.0     Mercedes EQS 580 4MATIC
# 31                  162              115000.0    Tesla Model S Long Range
# 32                  104              150000.0              Lightyear One
# ..                  ...                   ...                         ...
# 107                 158               23560.0  Fiat 500e Hatchback 24 kWh
# 73                  164               24790.0     Renault Twingo Electric
# 143                 167               18460.0       Smart EQ fortwo coupe
# 178                 176               21720.0      Smart EQ fortwo cabrio
# 101                 176               19120.0           Smart EQ forfour
#
# [214 rows x 9 columns]

# %%
# All of the top cars are extremely expensive so I need to find cars within my budget.
# I will create a new dataframe with cars within my budget

budg_ev_df = ev_df[(ev_df['Price_in_Germany (€)'] > 30000) & (ev_df['Price_in_Germany (€)'] < 50000)]

# I will apply the same sorting criteria to the new dataframe

budg_ev_df.sort_values(['Range_(km)', 'Price_in_Germany (€)', 'Efficiency_(Wh/km)'], ascending = [False, False, True])
# Out:
#            Make                 Model  Battery_(Kwh)  \
# 70        Skoda     Enyaq Coupe iV 80           77.0
# 35        CUPRA  Born 170 kW - 77 kWh           77.0
# 94   Volkswagen  ID.3 Pro S - 5 Seats           77.0
# 118  Volkswagen  ID.3 Pro S - 4 Seats           77.0
# 131       Skoda    Enyaq Coupe iV 80x           77.0
# ..          ...                   ...            ...
# 185     Citroen  e-Berlingo XL 50 kWh           45.0
# 80         Mini            Cooper SE            28.9
# 125       Honda             e Advance           28.5
# 46        Mazda                MX-30            30.0
# 19        Honda                    e            28.5
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 70                            8.7               160         455
# 35                            7.0               160         450
# 94                            7.9               160         450
# 118                           7.9               160         450
# 131                           7.0               160         430
# ..                            ...               ...         ...
# 185                          11.7               135         195
# 80                            7.3               150         185
# 125                           8.3               145         170
# 46                            9.7               140         170
# 19                            9.0               145         170
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)                       Make/Model
# 70                  169               47000.0          Skoda Enyaq Coupe iV 80
# 35                  171               44300.0       CUPRA Born 170 kW - 77 kWh
# 94                  171               42620.0  Volkswagen ID.3 Pro S - 5 Seats
# 118                 171               42460.0  Volkswagen ID.3 Pro S - 4 Seats
# 131                 179               49000.0         Skoda Enyaq Coupe iV 80x
# ..                  ...                   ...                              ...
# 185                 231               41040.0     Citroen e-Berlingo XL 50 kWh
# 80                  156               32500.0                  Mini Cooper SE
# 125                 168               38000.0                  Honda e Advance
# 46                  176               34490.0                     Mazda MX-30
# 19                  168               33850.0                         Honda e
#
# [76 rows x 9 columns]

# %%
# Some of the cars in this subsetted dataframe have really low range
# I will further subset this dataframe to only include cars with a minimum range of 400km 
# and a Fuel Efficiency of 180Wh/km or under

budg_ev_df = budg_ev_df[(budg_ev_df['Range_(km)'] > 400) & (budg_ev_df['Efficiency_(Wh/km)'] <= 180)]

#Applying the same sorting Criteria

budg_ev_df.sort_values(['Range_(km)', 'Price_in_Germany (€)', 'Efficiency_(Wh/km)'], ascending = [False, False, True])
# Out:
#            Make                      Model  Battery_(Kwh)  \
# 70        Skoda          Enyaq Coupe iV 80           77.0
# 35        CUPRA       Born 170 kW - 77 kWh           77.0
# 94   Volkswagen       ID.3 Pro S - 5 Seats           77.0
# 118  Volkswagen       ID.3 Pro S - 4 Seats           77.0
# 131       Skoda         Enyaq Coupe iV 80x           77.0
# 121  Volkswagen       ID.5 Pro Performance           77.0
# 115  Volkswagen                   ID.5 Pro           77.0
# 87         Audi     Q4 Sportback e-tron 40           76.6
# 41     Polestar  2 Long Range Single Motor           75.0
#
#      Acceleration_in_Secs_(1-100)  Top_Speed_(km/h)  Range_(km)  \
# 70                            8.7               160         455
# 35                            7.0               160         450
# 94                            7.9               160         450
# 118                           7.9               160         450
# 131                           7.0               160         430
# 121                           8.4               160         430
# 115                          10.4               160         430
# 87                            8.5               160         425
# 41                            7.4               160         425
#
#      Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 70                  169               47000.0
# 35                  171               44300.0
# 94                  171               42620.0
# 118                 171               42460.0
# 131                 179               49000.0
# 121                 179               47550.0
# 115                 179               46515.0
# 87                  180               49500.0
# 41                  176               48500.0
#
#                              Make/Model
# 70              Skoda Enyaq Coupe iV 80
# 35           CUPRA Born 170 kW - 77 kWh
# 94      Volkswagen ID.3 Pro S - 5 Seats
# 118     Volkswagen ID.3 Pro S - 4 Seats
# 131            Skoda Enyaq Coupe iV 80x
# 121     Volkswagen ID.5 Pro Performance
# 115                 Volkswagen ID.5 Pro
# 87          Audi Q4 Sportback e-tron 40
# 41   Polestar 2 Long Range Single Motor

# %% [markdown]
# From this analysis the Skoda Enyaq Coupe iV 80 and the Ford Mustang Mach-E would seem to be the best
# options based on my requirements and budget.
# Given the superior efficiency and range, along with the lower price, I will go with the Skoda.
# Next I will look at running costs.

# %%
# importing data outlining diesel and petrol prices in Ireland from 2014

# downloaded from https://www.theaa.ie/aa/motoring-advice/petrol-prices.aspx

# Data was downloaded as a pdf and extracted to CSV using tabula (https://tabula.technology/)

dsl_cst_df = pd.read_csv('tabula-FuelpricesHistory_Mar22 (3).csv')

print(dsl_cst_df.head(20))

print(dsl_cst_df.info())
# Out:
#      Month    Year Premium Super Unleaded     Reg Diesel
# 0      Mar  2022.0     NaN            NaN   182.4  190.5
# 1      Feb  2022.0     NaN            NaN   177.3  167.6
# 2   Jan-22  2022.0     NaN            NaN   175.5  166.1
# 3   Dec-21  2021.0     NaN            NaN   172.5  161.9
# 4      Nov  2021.0     NaN            NaN  172.6c  163.3
# 5      Oct  2021.0     NaN            NaN   164.6  156.6
# 6      NaN     NaN     NaN            NaN     +2c  +2.5c
# 7     Sept  2021.0     NaN            NaN   155.9  144.9
# 8      Aug  2021.0     NaN            NaN     155  144.4
# 9     July  2021.0     NaN            NaN   153.9  143.5
# 10    June  2021.0     NaN            NaN     150  140.1
# 11     May  2021.0     NaN            NaN   146.6  138.3
# 12     Apr  2021.0     NaN            NaN   142.9  133.8
# 13     Mar  2021.0     NaN            NaN   138.9  129.8
# 14     Feb  2021.0     NaN            NaN   133.8  124.9
# 15  Jan-21  2021.0     NaN            NaN   129.9  120.8
# 16  Dec-20  2020.0     NaN            NaN   127.3  119.0
# 17     Nov  2020.0     NaN            NaN   125.7  117.3
# 18     Oct  2020.0     NaN            NaN   126.4  118.5
# 19    Sept  2020.0     NaN            NaN   124.9  116.5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Month           99 non-null     object
#  1   Year            99 non-null     float64
#  2   Premium         4 non-null      object
#  3   Super Unleaded  2 non-null      object
#  4   Reg             101 non-null    object
#  5   Diesel          101 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 5.0+ KB
# None

# %%
# Checking for Null values
print(dsl_cst_df.isnull())
# Out:
#      Month   Year  Premium  Super Unleaded    Reg  Diesel
# 0    False  False     True            True  False   False
# 1    False  False     True            True  False   False
# 2    False  False     True            True  False   False
# 3    False  False     True            True  False   False
# 4    False  False     True            True  False   False
# ..     ...    ...      ...             ...    ...     ...
# 98   False  False     True            True  False   False
# 99   False  False     True            True  False   False
# 100  False  False     True            True  False   False
# 101  False  False     True            True  False   False
# 102  False  False    False            True  False   False
#
# [103 rows x 6 columns]

# %%
# Dropping columns that do not contain sufficient data

dsl_cst_df = dsl_cst_df.drop(['Premium', 'Super Unleaded'], axis=1,)

print(dsl_cst_df.head())
print(dsl_cst_df.info())
# Out:
#     Month    Year     Reg Diesel
# 0     Mar  2022.0   182.4  190.5
# 1     Feb  2022.0   177.3  167.6
# 2  Jan-22  2022.0   175.5  166.1
# 3  Dec-21  2021.0   172.5  161.9
# 4     Nov  2021.0  172.6c  163.3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   99 non-null     object
#  1   Year    99 non-null     float64
#  2   Reg     101 non-null    object
#  3   Diesel  101 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 3.3+ KB
# None

# %%
# Cleaning Data - Stripping out extraneous text

dsl_cst_df['Month'] = dsl_cst_df['Month'].str.replace(r'-\d{2}$', '', regex=True) 

dsl_cst_df['Reg'] = dsl_cst_df['Reg'].str.strip('r\+2c')

dsl_cst_df['Diesel'] = dsl_cst_df['Diesel'].str.strip('r\+2c')



# Dropping empty rows

dsl_cst_df = dsl_cst_df.dropna()

print(dsl_cst_df.info())

print(dsl_cst_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 102
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   99 non-null     object
#  1   Year    99 non-null     float64
#  2   Reg     99 non-null     object
#  3   Diesel  99 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 3.9+ KB
# None
#   Month    Year    Reg Diesel
# 0   Mar  2022.0  182.4  190.5
# 1   Feb  2022.0  177.3  167.6
# 2   Jan  2022.0  175.5  166.1
# 3   Dec  2021.0  172.5  161.9
# 4   Nov  2021.0  172.6  163.3

# %%
# Converting data types

dsl_cst_df['Reg'] = dsl_cst_df['Reg'].astype(float)

dsl_cst_df['Diesel'] = dsl_cst_df['Diesel'].astype(float)

dsl_cst_df['Year'] = dsl_cst_df['Year'].astype(int)



print(dsl_cst_df.info()) 

display(dsl_cst_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 102
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   99 non-null     object
#  1   Year    99 non-null     int32
#  2   Reg     99 non-null     float64
#  3   Diesel  99 non-null     float64
# dtypes: float64(2), int32(1), object(1)
# memory usage: 3.5+ KB
# None
#     Month  Year    Reg  Diesel
# 0     Mar  2022  182.4   190.5
# 1     Feb  2022  177.3   167.6
# 2     Jan  2022  175.5   166.1
# 3     Dec  2021  172.5   161.9
# 4     Nov  2021  172.6   163.3
# ..    ...   ...    ...     ...
# 98    May  2014  154.3   146.8
# 99    Apr  2014  153.0   147.1
# 100   Mar  2014  153.1   146.0
# 101   Feb  2014  152.1   146.7
# 102   Jan  2014  152.9   147.6
#
# [99 rows x 4 columns]

# %%
# In the

# %%
# Plotting the price in diesel since 2014. The graph shows increasing volatility in diesel prices since 2020 

sns.set(rc={'figure.figsize':(18,9)})

sns.lineplot(x='Year', y='Diesel', data=dsl_cst_df)

plt.show()

# %%
# I need to create Month Number, Qtr and Season columns to allow for merging with a future dataframe
# I created dictionaries to assign key:value pairs to allow for these columns to be created.

d = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'June': 6, 'July': 7, 'Aug': 8, 'Sept': 9, 'Oct':10, 'Nov':11, 'Dec':12}

q = {'Jan': 1, 'Feb': 1, 'Mar': 1, 'Apr': 2, 'May': 2, 'June': 2, 'July': 3, 'Aug': 3, 'Sept': 3, 'Oct':4, 'Nov':4, 'Dec':4}

r = {1:1, 2:1, 3:2, 4:2}

dsl_cst_df['Num_Month'] = dsl_cst_df['Month'].apply(lambda x: d.get(x))

dsl_cst_df['Qtr'] = dsl_cst_df['Month'].apply(lambda x: q.get(x))


print(dsl_cst_df.head())

print(dsl_cst_df.info())
# Out:
#   Month  Year    Reg  Diesel  Num_Month  Qtr
# 0   Mar  2022  182.4   190.5        3.0  1.0
# 1   Feb  2022  177.3   167.6        2.0  1.0
# 2   Jan  2022  175.5   166.1        1.0  1.0
# 3   Dec  2021  172.5   161.9       12.0  4.0
# 4   Nov  2021  172.6   163.3       11.0  4.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      99 non-null     object
#  1   Year       99 non-null     int32
#  2   Reg        99 non-null     float64
#  3   Diesel     99 non-null     float64
#  4   Num_Month  97 non-null     float64
#  5   Qtr        97 non-null     float64
# dtypes: float64(4), int32(1), object(1)
# memory usage: 7.1+ KB
# None

# %%
# Dataframe shows two null values in the Num_Month column
# Identifying the specific rows with null values

bool_series = pd.isnull(dsl_cst_df['Num_Month'])
dsl_cst_df[bool_series]
# Out:
#    Month  Year    Reg  Diesel  Num_Month  Qtr
# 84   Jul  2015  145.3   132.6        NaN  NaN
# 96   Jul  2014  157.4   147.6        NaN  NaN

# %%
#In the dictionaries 'd' and 'q' earlier in the code the month of July is written as 'July'
# In lines 84 and 96 July is written as 'Jul'
#Adding new Key: Value pair to the dictionary to resolve the issue

d['Jul'] = 7
q['Jul'] = 3

# Re-running the code to add month numbers and qtr

dsl_cst_df['Num_Month'] = dsl_cst_df['Month'].apply(lambda x: d.get(x))

dsl_cst_df['Qtr'] = dsl_cst_df['Month'].apply(lambda x: q.get(x))

dsl_cst_df['Season'] = dsl_cst_df['Qtr'].apply(lambda x: r.get(x))

# Checking if the issue has been resolved

print(dsl_cst_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      99 non-null     object
#  1   Year       99 non-null     int32
#  2   Reg        99 non-null     float64
#  3   Diesel     99 non-null     float64
#  4   Num_Month  99 non-null     int64
#  5   Qtr        99 non-null     int64
#  6   Season     99 non-null     int64
# dtypes: float64(2), int32(1), int64(3), object(1)
# memory usage: 7.9+ KB
# None

# %%
#Summary statistics for the dataframe

dsl_cst_df[['Reg' , 'Diesel']].describe()
# Out:
#               Reg      Diesel
# count   99.000000   99.000000
# mean   140.653535  130.986869
# std     12.623070   14.142212
# min    121.100000  105.400000
# 25%    131.500000  120.350000
# 50%    138.100000  129.800000
# 75%    146.350000  138.050000
# max    182.400000  190.500000

# %%
# Melting the Reg and Diesel columns to convert them to variables to allow for comparative analysis

melt_dsl_cst_df = pd.melt(dsl_cst_df, id_vars=['Month', 'Year', 'Num_Month', 'Qtr', 'Season'], value_vars = ['Diesel', 'Reg'], var_name = 'Fuel Type', value_name = 'Price (c)',  ignore_index = True)

print(melt_dsl_cst_df.head())
print(melt_dsl_cst_df.info())
# Out:
#   Month  Year  Num_Month  Qtr  Season Fuel Type  Price (c)
# 0   Mar  2022          3    1       1    Diesel      190.5
# 1   Feb  2022          2    1       1    Diesel      167.6
# 2   Jan  2022          1    1       1    Diesel      166.1
# 3   Dec  2021         12    4       2    Diesel      161.9
# 4   Nov  2021         11    4       2    Diesel      163.3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      198 non-null    object
#  1   Year       198 non-null    int32
#  2   Num_Month  198 non-null    int64
#  3   Qtr        198 non-null    int64
#  4   Season     198 non-null    int64
#  5   Fuel Type  198 non-null    object
#  6   Price (c)  198 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(2)
# memory usage: 10.2+ KB
# None

# %%
#PLotting out a timeline showing the changes in price in both petrol and diesel since 2014

sns.set(rc={'figure.figsize':(18,9)})

sns.lineplot(data = melt_dsl_cst_df, x = 'Year', y = 'Price (c)', hue = 'Fuel Type')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Price (c)'>

# %%
# Importing data on electricity prices in Ireland since 2014
# Data downloaded from https://ec.europa.eu/eurostat/data/database

ele_cst_df = pd.read_csv('nrg_pc_204__custom_2412797_page_csv.csv')
print(ele_cst_df.head())
# Out:
#       TIME  Ireland
# 0  2014-S1   0.2407
# 1  2014-S2   0.2536
# 2  2015-S1   0.2426
# 3  2015-S2   0.2454
# 4  2016-S1   0.2320

# %%
#renaming columns

ele_cst_df = ele_cst_df.rename(columns = {'TIME': 'Period', 'Ireland': 'Cost Kwh (€)'})

# Breaking down costs

ele_cst_df['Cost Kwh (c)'] = ele_cst_df['Cost Kwh (€)']*100

ele_cst_df['Cost Wh (c)'] = ele_cst_df['Cost Kwh (c)']/1000

print(ele_cst_df.head())

print(ele_cst_df.info())
# Out:
#     Period  Cost Kwh (€)  Cost Kwh (c)  Cost Wh (c)
# 0  2014-S1        0.2407         24.07      0.02407
# 1  2014-S2        0.2536         25.36      0.02536
# 2  2015-S1        0.2426         24.26      0.02426
# 3  2015-S2        0.2454         24.54      0.02454
# 4  2016-S1        0.2320         23.20      0.02320
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Period        15 non-null     object
#  1   Cost Kwh (€)  15 non-null     float64
#  2   Cost Kwh (c)  15 non-null     float64
#  3   Cost Wh (c)   15 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 608.0+ bytes
# None

# %%
# Summary statistics for Kwhr cost

print(ele_cst_df['Cost Kwh (c)'].describe().round(2))

sns.set(rc={'figure.figsize':(12,6)})

sns.lineplot(data = ele_cst_df, x = 'Period', y = 'Cost Kwh (c)')

plt.xticks(rotation = 75)
plt.show()
# Out:
# count    15.00
# mean     24.40
# std       0.97
# min      23.05
# 25%      23.62
# 50%      24.23
# 75%      25.38
# max      26.16
# Name: Cost Kwh (c), dtype: float64

# %%
# Data Cleaning

# Copying the last character in Period season addendum to the year and putting it in a new column

ele_cst_df['Season'] = ele_cst_df['Period'].map(lambda x: x[-1].split('-')[-1])
                                                                    
print(ele_cst_df.head())
# Out:
#     Period  Cost Kwh (€)  Cost Kwh (c)  Cost Wh (c) Season
# 0  2014-S1        0.2407         24.07      0.02407      1
# 1  2014-S2        0.2536         25.36      0.02536      2
# 2  2015-S1        0.2426         24.26      0.02426      1
# 3  2015-S2        0.2454         24.54      0.02454      2
# 4  2016-S1        0.2320         23.20      0.02320      1

# %%
#Adding in prices from 2021-S2 and 2022-S1

df = [{'Period':'2021-S2', 'Cost Kwh (€)': 0.2362, 'Cost Kwh (c)':23.62, 'Cost Wh (c)': 0.02362, 'Season': 2 } , {'Period':'2022-S1', 'Cost Kwh (€)': 0.2811, 'Cost Kwh (c)':28.11, 'Cost Wh (c)': 0.02811, 'Season': 1 }]

ele_cst_df = ele_cst_df.append(df, ignore_index = True)

# %%
#stripping out the last three characters of the first column and creatring a new Year column



ele_cst_df['Year'] = ele_cst_df['Period'].str[:4].replace(r'\d', '')


print(ele_cst_df.tail())
# Out:
#      Period  Cost Kwh (€)  Cost Kwh (c)  Cost Wh (c) Season  Year
# 12  2020-S1        0.2413         24.13      0.02413      1  2020
# 13  2020-S2        0.2616         26.16      0.02616      2  2020
# 14  2021-S1        0.2555         25.55      0.02555      1  2021
# 15  2021-S2        0.2362         23.62      0.02362      2  2021
# 16  2022-S1        0.2811         28.11      0.02811      1  2022

# %%
# Moving the Year column to the first position in the dataframe

#Popping off Year column

first_column = ele_cst_df.pop('Year')

#Inserting Year to index 0

ele_cst_df.insert(0, 'Year', first_column)

ele_cst_df['Year'] = ele_cst_df['Year'].astype(int)

ele_cst_df['Season'] = ele_cst_df['Season'].astype(int)

print(ele_cst_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          17 non-null     int32
#  1   Period        17 non-null     object
#  2   Cost Kwh (€)  17 non-null     float64
#  3   Cost Kwh (c)  17 non-null     float64
#  4   Cost Wh (c)   17 non-null     float64
#  5   Season        17 non-null     int32
# dtypes: float64(3), int32(2), object(1)
# memory usage: 808.0+ bytes
# None

# %%
# merging the fuel and electricity cost dataframes

nrg_cst_df = pd.merge(dsl_cst_df, ele_cst_df, how = 'left', left_on = ['Season', 'Year'], right_on = ['Season', 'Year'])

print(nrg_cst_df.head(50))
# Out:
#    Month  Year    Reg  Diesel  Num_Month  Qtr  Season   Period  Cost Kwh (€)  \
# 0    Mar  2022  182.4   190.5          3    1       1  2022-S1        0.2811
# 1    Feb  2022  177.3   167.6          2    1       1  2022-S1        0.2811
# 2    Jan  2022  175.5   166.1          1    1       1  2022-S1        0.2811
# 3    Dec  2021  172.5   161.9         12    4       2  2021-S2        0.2362
# 4    Nov  2021  172.6   163.3         11    4       2  2021-S2        0.2362
# 5    Oct  2021  164.6   156.6         10    4       2  2021-S2        0.2362
# 6   Sept  2021  155.9   144.9          9    3       2  2021-S2        0.2362
# 7    Aug  2021  155.0   144.4          8    3       2  2021-S2        0.2362
# 8   July  2021  153.9   143.5          7    3       2  2021-S2        0.2362
# 9   June  2021  150.0   140.1          6    2       1  2021-S1        0.2555
# 10   May  2021  146.6   138.3          5    2       1  2021-S1        0.2555
# 11   Apr  2021  142.9   133.8          4    2       1  2021-S1        0.2555
# 12   Mar  2021  138.9   129.8          3    1       1  2021-S1        0.2555
# 13   Feb  2021  133.8   124.9          2    1       1  2021-S1        0.2555
# 14   Jan  2021  129.9   120.8          1    1       1  2021-S1        0.2555
# 15   Dec  2020  127.3   119.0         12    4       2  2020-S2        0.2616
# 16   Nov  2020  125.7   117.3         11    4       2  2020-S2        0.2616
# 17   Oct  2020  126.4   118.5         10    4       2  2020-S2        0.2616
# 18  Sept  2020  124.9   116.5          9    3       2  2020-S2        0.2616
# 19   Aug  2020  127.5   118.5          8    3       2  2020-S2        0.2616
# 20  July  2020  125.9   117.3          7    3       2  2020-S2        0.2616
# 21  June  2020  121.8   113.9          6    2       1  2020-S1        0.2413
# 22   May  2020  123.7   115.5          5    2       1  2020-S1        0.2413
# 23   Apr  2020  126.9   116.9          4    2       1  2020-S1        0.2413
# 24   Mar  2020  126.5   116.9          3    1       1  2020-S1        0.2413
# 25   Feb  2020  141.9   133.4          2    1       1  2020-S1        0.2413
# 26   Jan  2020  144.5   135.9          1    1       1  2020-S1        0.2413
# 27   Dec  2019  141.7   131.4         12    4       2  2019-S2        0.2546
# 28   Nov  2019  141.6   131.0         11    4       2  2019-S2        0.2546
# 29   Oct  2019  143.9   133.7         10    4       2  2019-S2        0.2546
# 30  Sept  2019  144.7   134.4          9    3       2  2019-S2        0.2546
# 31   Aug  2019  141.3   131.5          8    3       2  2019-S2        0.2546
# 32  July  2019  139.5   129.9          7    3       2  2019-S2        0.2546
# 33  June  2019  143.9   133.4          6    2       1  2019-S1        0.2423
# 34   May  2019  146.1   136.8          5    2       1  2019-S1        0.2423
# 35   Apr  2019  142.3   137.0          4    2       1  2019-S1        0.2423
# 36   Mar  2019  136.0   133.0          3    1       1  2019-S1        0.2423
# 37   Feb  2019  134.5   129.8          2    1       1  2019-S1        0.2423
# 38   Jan  2019  132.9   127.9          1    1       1  2019-S1        0.2423
# 39   Dec  2018  136.9   131.9         12    4       2  2018-S2        0.2539
# 40   Nov  2018  146.9   138.9         11    4       2  2018-S2        0.2539
# 41   Oct  2018  147.9   141.9         10    4       2  2018-S2        0.2539
# 42  Sept  2018  145.9   139.9          9    3       2  2018-S2        0.2539
# 43   Aug  2018  144.9   135.8          8    3       2  2018-S2        0.2539
# 44  July  2018  143.8   134.0          7    3       2  2018-S2        0.2539
# 45  June  2018  147.6   137.8          6    2       1  2018-S1        0.2369
# 46   May  2018  141.0   131.0          5    2       1  2018-S1        0.2369
# 47   Apr  2018  137.6   127.1          4    2       1  2018-S1        0.2369
# 48   Mar  2018  137.0   126.5          3    1       1  2018-S1        0.2369
# 49   Feb  2018  138.1   127.7          2    1       1  2018-S1        0.2369
#
#     Cost Kwh (c)  Cost Wh (c)
# 0          28.11      0.02811
# 1          28.11      0.02811
# 2          28.11      0.02811
# 3          23.62      0.02362
# 4          23.62      0.02362
# 5          23.62      0.02362
# 6          23.62      0.02362
# 7          23.62      0.02362
# 8          23.62      0.02362
# 9          25.55      0.02555
# 10         25.55      0.02555
# 11         25.55      0.02555
# 12         25.55      0.02555
# 13         25.55      0.02555
# 14         25.55      0.02555
# 15         26.16      0.02616
# 16         26.16      0.02616
# 17         26.16      0.02616
# 18         26.16      0.02616
# 19         26.16      0.02616
# 20         26.16      0.02616
# 21         24.13      0.02413
# 22         24.13      0.02413
# 23         24.13      0.02413
# 24         24.13      0.02413
# 25         24.13      0.02413
# 26         24.13      0.02413
# 27         25.46      0.02546
# 28         25.46      0.02546
# 29         25.46      0.02546
# 30         25.46      0.02546
# 31         25.46      0.02546
# 32         25.46      0.02546
# 33         24.23      0.02423
# 34         24.23      0.02423
# 35         24.23      0.02423
# 36         24.23      0.02423
# 37         24.23      0.02423
# 38         24.23      0.02423
# 39         25.39      0.02539
# 40         25.39      0.02539
# 41         25.39      0.02539
# 42         25.39      0.02539
# 43         25.39      0.02539
# 44         25.39      0.02539
# 45         23.69      0.02369
# 46         23.69      0.02369
# 47         23.69      0.02369
# 48         23.69      0.02369
# 49         23.69      0.02369

# %%
nrg_cst_df = nrg_cst_df.rename(columns = {'Cost Kwh (c)': 'Electricity'})

print(nrg_cst_df.head(10))
# Out:
#   Month  Year    Reg  Diesel  Num_Month  Qtr  Season   Period  Cost Kwh (€)  \
# 0   Mar  2022  182.4   190.5          3    1       1  2022-S1        0.2811
# 1   Feb  2022  177.3   167.6          2    1       1  2022-S1        0.2811
# 2   Jan  2022  175.5   166.1          1    1       1  2022-S1        0.2811
# 3   Dec  2021  172.5   161.9         12    4       2  2021-S2        0.2362
# 4   Nov  2021  172.6   163.3         11    4       2  2021-S2        0.2362
# 5   Oct  2021  164.6   156.6         10    4       2  2021-S2        0.2362
# 6  Sept  2021  155.9   144.9          9    3       2  2021-S2        0.2362
# 7   Aug  2021  155.0   144.4          8    3       2  2021-S2        0.2362
# 8  July  2021  153.9   143.5          7    3       2  2021-S2        0.2362
# 9  June  2021  150.0   140.1          6    2       1  2021-S1        0.2555
#
#    Electricity  Cost Wh (c)
# 0        28.11      0.02811
# 1        28.11      0.02811
# 2        28.11      0.02811
# 3        23.62      0.02362
# 4        23.62      0.02362
# 5        23.62      0.02362
# 6        23.62      0.02362
# 7        23.62      0.02362
# 8        23.62      0.02362
# 9        25.55      0.02555

# %% [markdown]
# I'm not interested in Petrol cars so I will drop the Reg column

# %%
nrg_cst_df = pd.melt(nrg_cst_df, id_vars = ['Year', 'Month', 'Season'], 
                     value_vars = ['Diesel', 'Electricity'],
                     var_name = 'Fuel Type', value_name = 'Cost in (c)')

display(nrg_cst_df)
# Out:
#      Year Month  Season    Fuel Type  Cost in (c)
# 0    2022   Mar       1       Diesel       190.50
# 1    2022   Feb       1       Diesel       167.60
# 2    2022   Jan       1       Diesel       166.10
# 3    2021   Dec       2       Diesel       161.90
# 4    2021   Nov       2       Diesel       163.30
# ..    ...   ...     ...          ...          ...
# 193  2014   May       1  Electricity        24.07
# 194  2014   Apr       1  Electricity        24.07
# 195  2014   Mar       1  Electricity        24.07
# 196  2014   Feb       1  Electricity        24.07
# 197  2014   Jan       1  Electricity        24.07
#
# [198 rows x 5 columns]

# %%
nrg_cst_df['Cost in (c)'] = nrg_cst_df['Cost in (c)'].astype(int)

print(nrg_cst_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         198 non-null    int32
#  1   Month        198 non-null    object
#  2   Season       198 non-null    int64
#  3   Fuel Type    198 non-null    object
#  4   Cost in (c)  198 non-null    int32
# dtypes: int32(2), int64(1), object(2)
# memory usage: 6.3+ KB
# None

# %%
sns.relplot(data=nrg_cst_df, x = 'Year', y = 'Cost in (c)', col = 'Fuel Type', col_wrap = 2, kind = 'line')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Based on the initial analysis of the available electric cars the one that suited my needs most was the Skoda Eniyaq
# I will base my calculations on this car as well as my current car, a Megane Sport Tourer Estate.
# The Megane runs at 26.3km/l.
# Lets look at the Skoda specs again

# %%
budg_ev_df.loc[budg_ev_df['Make/Model'] == 'Skoda Enyaq Coupe iV 80']
# Out:
#      Make              Model  Battery_(Kwh)  Acceleration_in_Secs_(1-100)  \
# 70  Skoda  Enyaq Coupe iV 80           77.0                           8.7
#
#     Top_Speed_(km/h)  Range_(km)  Efficiency_(Wh/km)  Price_in_Germany (€)  \
# 70               160         455                 169               47000.0
#
#                  Make/Model
# 70  Skoda Enyaq Coupe iV 80

# %% [markdown]
# Now to calculate the cost per km for each car

# %%
# Calculating cost per km
# Writing a function to cycle through the Fuel Type row and apply a conversion factor based on Fuel Type
# My Megane runs at 26.3km/l and the Skoda runs at 5.9km/Kwh (conversion from Wh/km to km/Kwh done at aqua-calc.com)

def cost_km(row, x, y):
    if row['Fuel Type'] == 'Diesel' :
        return x
    if row['Fuel Type'] == 'Electricity' :
        return y
    return

 

nrg_cst_df['Conversion Factor'] = nrg_cst_df.apply(lambda row: cost_km(row, 26.3, 5.9), axis = 1)

nrg_cst_df['Cost per Km (c)'] = nrg_cst_df['Cost in (c)'] / nrg_cst_df['Conversion Factor']

display(nrg_cst_df)
# Out:
#      Year Month  Season    Fuel Type  Cost in (c)  Conversion Factor  \
# 0    2022   Mar       1       Diesel          190               26.3
# 1    2022   Feb       1       Diesel          167               26.3
# 2    2022   Jan       1       Diesel          166               26.3
# 3    2021   Dec       2       Diesel          161               26.3
# 4    2021   Nov       2       Diesel          163               26.3
# ..    ...   ...     ...          ...          ...                ...
# 193  2014   May       1  Electricity           24                5.9
# 194  2014   Apr       1  Electricity           24                5.9
# 195  2014   Mar       1  Electricity           24                5.9
# 196  2014   Feb       1  Electricity           24                5.9
# 197  2014   Jan       1  Electricity           24                5.9
#
#      Cost per Km (c)
# 0           7.224335
# 1           6.349810
# 2           6.311787
# 3           6.121673
# 4           6.197719
# ..               ...
# 193         4.067797
# 194         4.067797
# 195         4.067797
# 196         4.067797
# 197         4.067797
#
# [198 rows x 7 columns]

# %% [markdown]
# Hypothetical - Looking at what the the historical difference in cost would have been to run these cars.

# %%
sns.set_style("whitegrid")

sns.set(rc={'figure.figsize':(18,9)})

sns.lineplot(data = nrg_cst_df, x = 'Year', y = 'Cost per Km (c)', hue = 'Fuel Type')

plt.show()

# %%
# Checking cost per year based on current mileage
# Multiplying Cost per Km (c) by 350 to get the cost of 35000km driven per year

nrg_cst_df['Cost per Year (€)'] = nrg_cst_df['Cost per Km (c)'] * 350

sns.set(rc={'figure.figsize':(12,6)})

sns.catplot(data = nrg_cst_df, x = 'Year', y = 'Cost per Year (€)', hue = 'Fuel Type', kind = 'point')

plt.show()

nrg_cst_df[nrg_cst_df['Year'] == 2022]
# Out:
#      Year Month  Season    Fuel Type  Cost in (c)  Conversion Factor  \
# 0    2022   Mar       1       Diesel          190               26.3
# 1    2022   Feb       1       Diesel          167               26.3
# 2    2022   Jan       1       Diesel          166               26.3
# 99   2022   Mar       1  Electricity           28                5.9
# 100  2022   Feb       1  Electricity           28                5.9
# 101  2022   Jan       1  Electricity           28                5.9
#
#      Cost per Km (c)  Cost per Year (€)
# 0           7.224335        2528.517110
# 1           6.349810        2222.433460
# 2           6.311787        2209.125475
# 99          4.745763        1661.016949
# 100         4.745763        1661.016949
# 101         4.745763        1661.016949

# %% [markdown]
# The plot above shows a significant difference in the price of running a diesel car against an electric car at current prices,  €867 a year.
# However my current car will need to be changed anyway within the next year or so, so if I was to look at
# comparing the Skoda to another similar sized car how would that work out?
# For the purposes of this comparison I have used the Skoda Karoq 2.0l TDI Diesel SUV.
# This car is a similar size and shape to the Skoda Enyaq and runs at 20.3km/l

# %% [markdown]
# I will use the custom function *cost_km*, defined earlier, to change the data to facilitate the comparison
# between the Karoq and the Enyiaq

# %%
# Applying the cost_km function to the Conversion Factor series

nrg_cst_df['Conversion Factor'] = nrg_cst_df.apply(lambda row: cost_km(row, 20.3, 5.9), axis = 1)

# Recalculating dependent columns

nrg_cst_df['Cost per Km (c)'] = nrg_cst_df['Cost in (c)'] / nrg_cst_df['Conversion Factor']

# Calculating yearly running costs in € based on my annual distance driven

nrg_cst_df['Cost per Year (€)'] = nrg_cst_df['Cost per Km (c)'] * 350

# Plotting out the data

sns.set(rc={'figure.figsize':(18,9)})

sns.catplot(data = nrg_cst_df, x = 'Year', y = 'Cost per Year (€)', hue = 'Fuel Type', kind = 'point')

plt.show

nrg_cst_df[nrg_cst_df['Year'] == 2022]
# Out:
#      Year Month  Season    Fuel Type  Cost in (c)  Conversion Factor  \
# 0    2022   Mar       1       Diesel          190               20.3
# 1    2022   Feb       1       Diesel          167               20.3
# 2    2022   Jan       1       Diesel          166               20.3
# 99   2022   Mar       1  Electricity           28                5.9
# 100  2022   Feb       1  Electricity           28                5.9
# 101  2022   Jan       1  Electricity           28                5.9
#
#      Cost per Km (c)  Cost per Year (€)
# 0           9.359606        3275.862069
# 1           8.226601        2879.310345
# 2           8.177340        2862.068966
# 99          4.745763        1661.016949
# 100         4.745763        1661.016949
# 101         4.745763        1661.016949

# %% [markdown]
# With the higher fuel consumption of the Skoda Karoq the gap widens even further, to €1614 a year (€3275 - €1661).
# Over 5 years this would equate to a fuel saving of €8070.

# %% [markdown]
# The price difference between the two cars is €12100.
# At this price difference it would take 7.5 years based on fuel consumption costs alone to recoup the extra
# cost of purchasing the electric car. I would like to be able to recoup these costs over a shorter period, preferably in under 5 years.

# %% [markdown]
# In order for this to work the savings per year would need to be over €2420

# %% [markdown]
# Fortunately in my workplace I have access to free fast charging station with which to charge an electric car.
# I would like to figure out what percentage of my charging I would need to do at work
# to make the switch to electric financially attractive.

# %% [markdown]
# # Calculating 5 Year Costs

# %%
five_yr_cost = [[2022, 34900, 47000], [2022, 3275, 1661], [2023, 3275, 1661],
            [2024, 3275, 1661], [2025, 3275, 1661], [2026, 3275, 1661],
            [2027, 3275, 1661], [2028, 3275, 1661], [2029, 3275, 1661],
            [2030, 3275, 1661]]
five_yr_df = pd.DataFrame(five_yr_cost, columns = ['Year', 'Karoq', 'Enyiaq'])

print(five_yr_df.head(10))
# Out:
#    Year  Karoq  Enyiaq
# 0  2022  34900   47000
# 1  2022   3275    1661
# 2  2023   3275    1661
# 3  2024   3275    1661
# 4  2025   3275    1661
# 5  2026   3275    1661
# 6  2027   3275    1661
# 7  2028   3275    1661
# 8  2029   3275    1661
# 9  2030   3275    1661

# %%
def free_chrg(row,  x):
    if row['Enyiaq'] < 47000 :
        return row['Enyiaq'] * x
    return 47000

five_yr_df['Enyiaq_10%'] = five_yr_df.apply(lambda row: free_chrg(row, .9), axis = 1)
five_yr_df['Enyiaq_20%'] = five_yr_df.apply(lambda row: free_chrg(row, .8), axis = 1)
five_yr_df['Enyiaq_30%'] = five_yr_df.apply(lambda row: free_chrg(row, .7), axis = 1)
five_yr_df['Enyiaq_40%'] = five_yr_df.apply(lambda row: free_chrg(row, .6), axis = 1)
five_yr_df['Enyiaq_50%'] = five_yr_df.apply(lambda row: free_chrg(row, .5), axis = 1)
five_yr_df['Enyiaq_60%'] = five_yr_df.apply(lambda row: free_chrg(row, .4), axis = 1)
five_yr_df['Enyiaq_70%'] = five_yr_df.apply(lambda row: free_chrg(row, .3), axis = 1)
five_yr_df['Enyiaq_80%'] = five_yr_df.apply(lambda row: free_chrg(row, .2), axis = 1)

print(five_yr_df.head())
# Out:
#    Year  Karoq  Enyiaq  Enyiaq_10%  Enyiaq_20%  Enyiaq_30%  Enyiaq_40%  \
# 0  2022  34900   47000     47000.0     47000.0     47000.0     47000.0
# 1  2022   3275    1661      1494.9      1328.8      1162.7       996.6
# 2  2023   3275    1661      1494.9      1328.8      1162.7       996.6
# 3  2024   3275    1661      1494.9      1328.8      1162.7       996.6
# 4  2025   3275    1661      1494.9      1328.8      1162.7       996.6
#
#    Enyiaq_50%  Enyiaq_60%  Enyiaq_70%  Enyiaq_80%
# 0     47000.0     47000.0     47000.0     47000.0
# 1       830.5       664.4       498.3       332.2
# 2       830.5       664.4       498.3       332.2
# 3       830.5       664.4       498.3       332.2
# 4       830.5       664.4       498.3       332.2

# %%
#Adding Cumulative cost column

cols = five_yr_df.loc[1: 10]

for col in cols:
    
    if col != 'Year':
        five_yr_df[col] = five_yr_df[col].cumsum()
        
    else:
        five_yr_df[col] = five_yr_df[col]
       
    
#five_yr_df['Enyiaq_10%'] = five_yr_df.apply(lambda row: free_chrg(row, .9), axis = 1)
    

#five_yr_df['CUM_Karoq'] = five_yr_df['Karoq'].cumsum()
#five_yr_df['CUM_Enyiaq'] = five_yr_df['Enyiaq'].cumsum()
print(five_yr_df.head())
# Out:
#    Year  Karoq  Enyiaq  Enyiaq_10%  Enyiaq_20%  Enyiaq_30%  Enyiaq_40%  \
# 0  2022  34900   47000     47000.0     47000.0     47000.0     47000.0
# 1  2022  38175   48661     48494.9     48328.8     48162.7     47996.6
# 2  2023  41450   50322     49989.8     49657.6     49325.4     48993.2
# 3  2024  44725   51983     51484.7     50986.4     50488.1     49989.8
# 4  2025  48000   53644     52979.6     52315.2     51650.8     50986.4
#
#    Enyiaq_50%  Enyiaq_60%  Enyiaq_70%  Enyiaq_80%
# 0     47000.0     47000.0     47000.0     47000.0
# 1     47830.5     47664.4     47498.3     47332.2
# 2     48661.0     48328.8     47996.6     47664.4
# 3     49491.5     48993.2     48494.9     47996.6
# 4     50322.0     49657.6     48993.2     48328.8

# %% [markdown]
# # Writing a custom function to add further columns with percentage of free charging
#
# def free_chrg(row,  x):
#     if row['CUM_Enyiaq'] > 47001 :
#         return row['CUM_Enyiaq'] - 1661 * x
#     return 47000
#
# five_yr_df['CUM_Enyiaq_10%'] = five_yr_df.apply(lambda row: free_chrg(row, .1), axis = 1)
# five_yr_df['CUM_Enyiaq_20%'] = five_yr_df.apply(lambda row: free_chrg(row, .2), axis = 1)
# five_yr_df['CUM_Enyiaq_30%'] = five_yr_df.apply(lambda row: free_chrg(row, .3), axis = 1)
# five_yr_df['CUM_Enyiaq_40%'] = five_yr_df.apply(lambda row: free_chrg(row, .4), axis = 1)
# five_yr_df['CUM_Enyiaq_50%'] = five_yr_df.apply(lambda row: free_chrg(row, .5), axis = 1)
# five_yr_df['CUM_Enyiaq_60%'] = five_yr_df.apply(lambda row: free_chrg(row, .6), axis = 1)
# five_yr_df['CUM_Enyiaq_70%'] = five_yr_df.apply(lambda row: free_chrg(row, .7), axis = 1)
# five_yr_df['CUM_Enyiaq_80%'] = five_yr_df.apply(lambda row: free_chrg(row, .8), axis = 1)
#
# print(five_yr_df.tail())

# %%
# Melting the DataFrame to allow for plotting

melt_fiveyr_df = pd.melt(five_yr_df, id_vars = ['Year'], value_vars = ['Karoq',
                        'Enyiaq', 'Enyiaq_10%', 'Enyiaq_20%',
                        'Enyiaq_30%', 'Enyiaq_40%', 'Enyiaq_50%', 'Enyiaq_60%', 'Enyiaq_70%', 'Enyiaq_80%'],
                         var_name = 'Model', value_name = 'CUM_Cost')

print(melt_fiveyr_df.head(100))
# Out:
#     Year       Model  CUM_Cost
# 0   2022       Karoq   34900.0
# 1   2022       Karoq   38175.0
# 2   2023       Karoq   41450.0
# 3   2024       Karoq   44725.0
# 4   2025       Karoq   48000.0
# ..   ...         ...       ...
# 95  2026  Enyiaq_80%   48661.0
# 96  2027  Enyiaq_80%   48993.2
# 97  2028  Enyiaq_80%   49325.4
# 98  2029  Enyiaq_80%   49657.6
# 99  2030  Enyiaq_80%   49989.8
#
# [100 rows x 3 columns]

# %%
melt_fiveyr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      100 non-null    int64
#  1   Model     100 non-null    object
#  2   CUM_Cost  100 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
#Plotting out the cumulative costs of running the Enyiaq with different levels of free charging.

sns.set(rc={'figure.figsize':(18,9)})

sns.lineplot(data=melt_fiveyr_df, x = 'Year', y = 'CUM_Cost', hue = 'Model')


plt.show()

# %% [markdown]
# The data confirms that based on purchase price and fuel costs I would need to be using free charging points for
# 30% of my charging to make the extra price of the electric car make sense.
# Using free charging points for 80% of my charging would cut the time down from five years to just over three years.

# %% [markdown]
# This analysis doesn't factor in variables such as servicing costs, depreciation, charger proliferation,
# oil price volatility and many other well worth consideration in making a decision like this.

# %% [markdown]
# Another interesting learning from this analysis for me was the fact that the investment makes sense for me because of my high mileage.
# I'm not sure the investment would make sense from a financial perspective for a driver driving closer the national average
# of around 20000km (https://www.ccpc.ie/consumers/cars/car-clocking)

# %% [markdown]
# Conversely my high mileage would bring me over the recommended lifespan of the car battery (160000km)

# %% [markdown]
# I'm not sure yet whether an electric car is the right choice for me but I definitely have a better grasp of the
# pros and cons.
